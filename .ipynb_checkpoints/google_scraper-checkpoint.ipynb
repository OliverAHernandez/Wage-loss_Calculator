# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
import time
# These are the modules needed for this operation

# %%
dis = pd.read_csv('./data/DisasterDeclarationsSummaries.csv') # Reading in disaster data from a csv

# %%
dis.tail()
# Out:
#        disasterNumber  ihProgramDeclared  iaProgramDeclared  \
# 51011            4473                  1                  0
# 51012            4473                  1                  0
# 51013            4473                  1                  0
# 51014            4473                  1                  0
# 51015            4473                  1                  0
#
#        paProgramDeclared  hmProgramDeclared state           declarationDate  \
# 51011                  0                  0    PR  2020-01-16T14:48:00.000Z
# 51012                  0                  0    PR  2020-01-16T14:48:00.000Z
# 51013                  0                  0    PR  2020-01-16T14:48:00.000Z
# 51014                  0                  0    PR  2020-01-16T14:48:00.000Z
# 51015                  0                  0    PR  2020-01-16T14:48:00.000Z
#
#        fyDeclared disasterType incidentType        title  \
# 51011        2020           DR   Earthquake  EARTHQUAKES
# 51012        2020           DR   Earthquake  EARTHQUAKES
# 51013        2020           DR   Earthquake  EARTHQUAKES
# 51014        2020           DR   Earthquake  EARTHQUAKES
# 51015        2020           DR   Earthquake  EARTHQUAKES
#
#               incidentBeginDate incidentEndDate disasterCloseOutDate  \
# 51011  2019-12-28T04:29:00.000Z             NaN                  NaN
# 51012  2019-12-28T04:29:00.000Z             NaN                  NaN
# 51013  2019-12-28T04:29:00.000Z             NaN                  NaN
# 51014  2019-12-28T04:29:00.000Z             NaN                  NaN
# 51015  2019-12-28T04:29:00.000Z             NaN                  NaN
#
#               declaredCountyArea  placeCode                              hash  \
# 51011  Sabana Grande (Municipio)    99121.0  2fc70c181ea2812349c328633f2432e3
# 51012     Juana Diaz (Municipio)    99075.0  96d675c0cd6e7e68c97631c1aae76c04
# 51013       Mayaguez (Municipio)    99097.0  04baba2a215b8af556e3b16dd5253413
# 51014    Hormigueros (Municipio)    99067.0  1125cacf13706fc3c347b1f75ca79a35
# 51015        Arecibo (Municipio)    99013.0  7e242aa5873d5adac5a3776a714cbd79
#
#                     lastRefresh                        id
# 51011  2020-02-05T23:40:50.716Z  5e3b528274cbd479fcb5c27b
# 51012  2020-02-05T23:40:50.715Z  5e3b528274cbd479fcb5c278
# 51013  2020-02-05T23:40:50.714Z  5e3b528274cbd479fcb5c276
# 51014  2020-02-05T23:40:50.715Z  5e3b528274cbd479fcb5c277
# 51015  2020-02-05T23:40:50.717Z  5e3b528274cbd479fcb5c27c

# %%
set(dis.title) # Checking for unique titles on these events
# Out:
# {'HEAVY RAINS, ICE JAMS & FLOODING',
#  'FLOODING ASSOCIATED WITH TROPICAL DEPRESSION FRAN',
#  'SHEKELL FIRE',
#  'MT - MISSOURI BREAKS COMPLEX FIRE 07/16/03',
#  'CEDAR LANE FIRE',
#  'LANDSLIDES',
#  'WALDO CANYON FIRE',
#  'STORMS & FLASH FLOODS',
#  'MI - SEVERE WEATHER 1/2 /99',
#  'ASH CREEK FIRE',
#  'PEPPIN FIRE',
#  'PUAKO FIRE',
#  'GA - BLOUNTS PASTURE FIRE',
#  'CA-EAGLE FIRE-05-04-2004',
#  'TRINITY RIDGE FIRE',
#  'SEVERE WEATHER CONDITIONS',
#  'PEDERNALES BEND FIRE',
#  'FAIR GROUNDS FIRE COMPLEX',
#  'FL - ESCAMBIA FIRE COMPLEX - 05/16/01',
#  'EXTREME  FIRE HAZARD',
#  'RIM ROCK FIRE',
#  'SEVERE STORMS, FLOODING, SNOW MELT AND ICE JAMS',
#  'WELLNITZ FIRE',
#  'HIGH WINDS, SEVERE  STORMS AND FLOODING',
#  'HEAVY RAINS, FLOODING & MUDSLIDES',
#  'TYPHOON LOLA',
#  'HURRICANE DOLLY',
#  'HURRICANE, TORRENTIAL RAIN & FLOODS',
#  'FREEZING TEMPERATURES',
#  'SEVERE STORM, FLOODING, AND TORNADOES',
#  'WILDFIRES AND HIGH WINDS',
#  'SUZIE FIRE',
#  'DONALDSON FIRE',
#  'SEVERE STORMS, SNOWMELT & FLOODING',
#  'DROUGHT & IMPENDING FREEZE',
#  'UNION VALLEY FIRE',
#  'BASIN FIRE COMPLEX',
#  'POTENTIAL FAILURE OF THE EMERGENCY SPILLWAY AT OROVILLE LAKE',
#  'SEVERE FLOODING',
#  'LOLO PEAK FIRE',
#  'TROPICAL STORM ISIDORE',
#  'LOWER NORTH FORK FIRE',
#  'CO - HAYMEN FIRE - 06/09/02',
#  'BRINS FIRE',
#  'TYPHOON WUTIP',
#  'BLUE CREEK FIRE',
#  'AK - RED FOX FIRE - 06/30/01',
#  'CANYON CREEK FIRE',
#  'EARTHQUAKES & VOLCANIC DISTURBANCES',
#  'MT - SOUTH CENTRAL ZONE 4 FIRE COMPLEX',
#  'CO - PANORAMA FIRE - 07/31/02',
#  'HIGH WINDS, FREEZING RAIN, HEAVY SNOWFALL',
#  'TIMBERON FIRE',
#  'KENTWOOD FIRE',
#  'SEVERE  WINTER STORM',
#  'WA TONASKET FIRE COMPLEX 2376',
#  'CHIMNEY FIRE',
#  'TROPICAL STORM HELENE',
#  'JACKSON CANYON FIRE',
#  'SEVERE WINTER STORMS, TORNADOES, STRAIGHT-LINE WINDS, AND FLOODING',
#  'NM - DALTON FIRE - 05/06/02',
#  'TROPICAL STORM GASTON',
#  'CARIBOU HILLS FIRE',
#  'HIGH WINDS, WAVE ACTION & FLOODING',
#  'TORNADOES & FLOODS',
#  'CA - PINES FIRE - 07/30/02',
#  'SEVERE STORMS,MUDSLIDES, & FLOODING',
#  'SISK ROAD FIRE',
#  'MI - TOWER LAKE MOUNTAIN FIRE - 05/06/1999',
#  'TN - COOKEVILLE FIRE COMPLEX - 11/03/00',
#  'BRIDGE FIRE',
#  'CLYDE FIRE',
#  'FL - OKEECHOBEE COMPLEX FIRE',
#  'FLOODING, HEAVY WINDS',
#  'SEVERE WINTER STORM',
#  'MUSTANG ROAD FIRE',
#  'HURRICANE EARL',
#  'HEAVY RAINS, MELTING SNOWS & FLOODING',
#  'PEAVINE FIRE',
#  'HEAVY RAINS, HIGH WINDS, FLOODING, AND SLIDES',
#  'TIMBERED ROCK FIRE',
#  'DAY FIRE',
#  'SPROMBERG FIRE',
#  'BLIZZARD OF 96 (SEVERE SNOW STORM)',
#  'HURRICANE IKE',
#  'TYPHOON ZELDA',
#  'CANYON CREEK FIRE COMPLEX',
#  'BUTLER 2 FIRE',
#  'RIV-SEVERE WINTER WX 12/23/98',
#  'POISON FIRE',
#  'TSUNAMI WAVES',
#  'FL, WACCASASSA FIRE COMPLEX',
#  'BADGER CREEK FIRE',
#  'NASH RANCH FIRE',
#  'DROUGHT',
#  'MOSLEY ROAD FIRE',
#  'HEAVY & WIND DRIVEN RAIN, HIGH WINDS,FLOODING,SLIDES',
#  'EXTREME WEATHER CONDITIONS AND FLOODING',
#  'SD - BATTLE CREEK FIRE - 08/18/02',
#  "SEVERE STORMS AND FLOODING ASSOCIATED WITH TROPICAL DEPRESSION IDA AND A NOR'EAST",
#  'ROOKS COUNTY FIRE',
#  'SEVERE WINTER ICE STORM',
#  'POWERHOUSE FIRE',
#  'TORNADO AND SEVERE STORMS',
#  'TWO BULLS FIRE',
#  'SCHOOL FIRE',
#  'SEVERE STORMS, HIGH WINDS, AND HEAVY RAIN',
#  'HURRICANE CLEO',
#  'AZ - RAINBOW FIRE - 06/11/1999',
#  'NM-WALKER FIRE-05-09-03',
#  'OKANAGAN COUNTY FIRE COMPLEX',
#  'WY - MCFARLAND DIVIDE FIRE - 09/06/01',
#  'HIGH MEADOWS FIRE',
#  'VOLUSIA FIRE COMPLEX',
#  'BELEN FIRE',
#  'SEVERE STORMS AND FLOODING (TROPICAL STORM ALBERTO)',
#  'OJO FELIZ FIRE',
#  'NANAKULI BRUSH FIRE',
#  'TN - WILDFIRES 4/13/99',
#  'TYPHOON SOUDELOR',
#  'PA - FLOODING 8/20/99',
#  'OREGON FIRE',
#  'WATER MAIN BREAK',
#  'FLASH FLOOD DUE TO DAM FAILURE',
#  'MIDWEST CHOCTAW FIRE',
#  'TROPICAL DEPRESSION DENNIS PA',
#  'HURRICANE GEORGES - 18 SEP 98',
#  'HURRICANE CLAUDETTE',
#  'THEDFORD FIRE',
#  'COMANCHE COUNTY FIRE',
#  'RED APPLE FIRE',
#  'WESTMINSTER FIRE',
#  'SEVERE WINDS & BLIZZARD, RECORD SNOWFALL',
#  'HURRICANE BRET',
#  'EXPLOSION AT FEDERAL COURTHOUSE IN OKLAHOMA CITY',
#  'EARTHQUAKE, SEISMIC WAVES & VOLCANIC ERUPTION',
#  'BEAR CREEK FIRE',
#  'NV - SPRING CREEK FIRE - 1999',
#  'WILDLAND FIRES',
#  'TYPHOON OWEN',
#  'SEVERE STORMS & HIGH WINDS',
#  'SEVERE STORMS, FLOODING, TIDAL SURGE, LANDSLIDES, AND MUDSLIDES',
#  'HURRICANE LILI',
#  'ANDREW WILDFIRE',
#  'GARNER FIRE COMPLEX',
#  'BULL FIRE',
#  'SOBERANES FIRE',
#  'BRYSON FIRE COMPLEX',
#  'TURLEY FIRE',
#  'FOREST & BRUSH FIRES',
#  'HURRICANE ALLEN',
#  'TYPHOON ALICE',
#  'WEST NILE VIRUS',
#  'CANYON FIRE',
#  'HAWAIIAN BEACHES SUBDIVISION FIRE',
#  'SNOW',
#  'TROPICAL STORM DORIAN',
#  'GETTY FIRE',
#  'MCDONALD 2 FIRE',
#  'FIRES',
#  'SNOWSTORMS',
#  'MCKINLEY FIRE',
#  'SEVERE STORMS, TORNADOES, FLOODING, LANDSLIDES, AND MUDSLIDES',
#  'AL - COUNTY LINE FIRE - 09/17/2000',
#  'PACIFICA FIRE',
#  'LEONA FIRE',
#  'TYPHOON PONGSONA',
#  'SEVERE SNOW AND ICE STORM',
#  'SHAWNEE FIRE',
#  'WILDFIRES, FLOODING, MUDFLOWS, AND DEBRIS FLOWS',
#  'SEVERE STORMS, LANDSLIDES & FLOODING',
#  'WOODY FIRE',
#  'EARTHQUAKE & AFTERSHOCKS',
#  'SEVERE ICE STORM AND FLOODING',
#  'SEVERE STORMS, MUDSLIDES, LANDSLIDES & FLOODING',
#  'STORMS, HIGH TIDES, MUDSLIDES & FLOODING',
#  'SEVERE WINTER STORM, LANDSLIDES, AND MUDSLIDES',
#  'SNYDER FIRE',
#  'RECORD SNOW',
#  'TWO FORK FIRE',
#  'HIGH PARK FIRE',
#  'INDIAN LAKE ESTATES FIRE',
#  'SADDLE MOUNTAIN FIRE',
#  'TUBBS FIRE',
#  'HEAVY RAINS & LANDSLIDE',
#  'SEVERE WINTER STORM AND RECORD AND/OR NEAR RECORD SNOW',
#  'SEVERE STORMS, HIGH TIDES & FLOODING',
#  'KILAUEA VOLCANIC ERUPTION AND EARTHQUAKES',
#  'TORNADO & SEVERE STORM',
#  'COOPER MOUNTAIN RANCH FIRE',
#  'LAKE OLYMPIA FIRE',
#  'ICE CONDITIONS',
#  'HURRICANE GRORGES',
#  'KOHALA MOUNTAIN ROAD FIRE',
#  'SEVERE STORMS AND FLOODING DUE TO THE REMNANTS OF HURRICANE SANDY',
#  'BIG OAK FIRE',
#  'TORNADO & SEVERE STORMS',
#  'BETHEL ACRES FIRE',
#  'SEVERE STORMS, FLOODING AND GROUND SATURATION',
#  'LANE 2 FIRE',
#  'PAWNEE COVE FIRE',
#  'PURGATORY ROAD FIRE',
#  'TROPICAL STORM BONNIE AND HURRICANE CHARLEY',
#  'KINISHBA FIRE',
#  'TX - AMHURST STREET FIRE - 09/04/00',
#  'BURNS RANCH FIRE',
#  'TROPICAL STORMS HENRI AND ISABEL AND RELATED SEVERE STORMS AND FLOODING',
#  'EXPLOSIONS',
#  'SEVERE STORMS, ICING, WIND & FLOODING',
#  'AZ-HUMBUG FIRE 06-23--2005',
#  'EAST MILLER COVE FIRE',
#  'COMANCHE FIRE COMPLEX',
#  'HURRICANE HUGO',
#  'PAT GROSS FIRE',
#  'SEVERE STORMS, ICE JAMS, FLOODING',
#  'CAVE FIRE',
#  'WILDLAND FIRE',
#  'BLIZZARD 0F 96',
#  'FOREST FIRE',
#  'SEVERE WINTER STORMS, FLOODING, LANDSLIDES, MUD FLOWS',
#  'HURRICANE OMAR',
#  'FORD COUNTY FIRE COMPLEX',
#  'OK-ARBUCKLE FIRE COMPLEX-9/18/00',
#  'CLEARWATER LAWYER BRANCH FIRE COMPLEX',
#  'TROPICAL STORM ERIN',
#  'VENUS FIRE COMPLEX',
#  'SEVERE STORMS, HIGH WINDS & FLOODING',
#  'TYPHOON PAKA, TORRENTIAL RAINS, HIGH WINDS, HIGH SURF',
#  'GOLDSBY FIRE',
#  'MILLION FIRE',
#  'SEVERE WINTER STORMS, STRAIGHT-LINE WINDS, FLOODING, LANDSLIDES, MUDSLIDES, TORNADO',
#  'HILL FIRE',
#  'TYPHOON YURI',
#  'HURRICANE DIANA',
#  'SEVERE WINTER STORM, LANDSLIDES, MUDSLIDES, AND FLOODING',
#  'GAP FIRE',
#  'FL - MERRITT FIRE',
#  'HEAVY RAINS, HAIL, FLOODS & TORNADOES',
#  'SEVERE STORM,HEAVY RAINS, FLOODING, HIGH WINDS',
#  'GOTEBO FIRE',
#  'BORDER 3 FIRE',
#  'TRACK FIRE',
#  'SUPER TYPHOON YUTU',
#  'SANTA ANITA FIRE',
#  'HEALDTON CARTER FIRE',
#  'SEVERE WINTER COASTAL STORM, HIGH WINDS, FLOODING',
#  'ANGORA FIRE',
#  'ASH FIRE',
#  'CARR FIRE',
#  'CHESTNUT KNOB FIRE',
#  'BUCKSHOT FIRE',
#  'RYE FIRE',
#  'TROPICAL STORM BARRY',
#  'SEVERE FLOODING, HIGH WINDS,SEVERE STORMS',
#  'WAIKELE FIRE',
#  'DIRTY FACE FIRE',
#  'SEVERE STORMS, FLOODING, MUDSLIDES AND LANDSLIDES',
#  'DAWES COUNTY FIRE COMPLEX',
#  'REIN STREET FIRE',
#  'LITTLE LEWIS FIRE',
#  'NM - BORREGO FIRE - 5-23-02',
#  'HEAVY RAINS & FLOODING',
#  'SEVERE WINTER STORM, FLOODING, MUDSLIDES, LANDSLIDES, AND DEBRIS FLOWS',
#  'DUCKETT FIRE',
#  'SEVERE STORMS, STRAIGHT-LINE WINDS, TORNADOES, AND',
#  'OR - WINTER FIRE - 07/15/2002',
#  'COLD SPRINGS FIRE',
#  'SEVERE STORMS AND FLOODING FROM THE REMANANTS OF HURRICANE JEANNE',
#  'MT-CHERRY CREEK FIRE -08/06/03',
#  'TX-GREENVILLE FIRE',
#  'DEAN PEAK FIRE',
#  'CREE FIRE',
#  'HEAVY RAIN, SNOWMELT, ICE JAMS & FLOODING',
#  'SEVERE FREEZING',
#  'NV - ARROWCREEK FIRE',
#  'AZ - INDIAN FIRE - 5/15/2002',
#  'SEVERE STORMS,STRAIGH LINE WINDS, TORNADOES,RAIN,AND FLOODI',
#  'TEPEE SPRINGS FIRE',
#  'SEVERE STORMS, TORNADOES, FLOODING, AND STRAIGHT-LINE WINDS',
#  'MCNALLY FLATS FIRE',
#  'RODEO FIRE',
#  'TX - WARREN CHAPEL FIRE - 09/04/00',
#  'MILLS CANYON FIRE',
#  'HEAVY RAINS & FLASH',
#  'PINEHAVEN FIRE',
#  'SEVERE STORMS, FLOOD, MUDSLIDES & HIGH TIDE',
#  'KY - EASTERN DISTRICT FIRE COMPLEX - 11/03/00',
#  'BRIDGE COLLAPSE',
#  'TROPICAL STORM MITCH',
#  'TEA FIRE',
#  'NM - ROYBAL FIRE - 06/13/02',
#  'CEDAR CREEK FIRE',
#  'SEVERE STORMS, FLOODING, LANDSLIDES, AND MUD AND DEBRIS FLOWS',
#  'FL-FIRES 04/13/99',
#  'ORDWAY FIRE',
#  'KRAUSS LANE FIRE',
#  'HURRICANE',
#  'SEVERE BLIZZARD',
#  "TYPHOON CHATA'AN",
#  'RANCH FIRE',
#  'COLUMBIA FIRE COMPLEX',
#  'SEVERE STORMS, FLOODING, DEBRIS FLOWS, AND MUDSLIDES',
#  'HURRICANE ALICIA',
#  'TROPICAL STORM FRANCES',
#  'SEVERE STORMS, FLOODING, MUDSLIDES, AND LANDSLIDES ASSOC W TS OTTO',
#  'SEVERE STORMS, RAINS & TORNADOES',
#  'NV-ROBB WILDFIRE-7-14-2003',
#  'COASTAL STORM, HIGH WINDS & WAVES',
#  'SEVERE WINTER STORMS, LAND AND MUDSLIDES, FLOODING',
#  'FL - CHIPOLA RIVER FIRE COMPLEX - 05/15/01',
#  'SEVERE STORM & FLOODING',
#  'HIGHLAND HILLS FIRE',
#  'EDMOND FIRE',
#  'FLOODING, SEVERE STORMS, TORNADOES',
#  'STORMS & FLOODING',
#  'SEVERE STORM',
#  'SPOKANE VALLEY FIRE',
#  'HURRICANE INIKI',
#  'GOOD SPRINGS FIRE',
#  'MT - NORTHWESTERN ZONE 1 FIRE COMPLEX',
#  'CA - PLEASURE FIRE - 04-25-2004',
#  'SEVERE STORM, TORNADOES, FLOODING, LANDSLIDES, AND MUDSLIDES',
#  'FLOODING, SEVERE STORMS AND TORNADOES',
#  'TYPHOON MANGKHUT',
#  'EMERALD HILLS FIRE',
#  'RYAN FIRE',
#  'TANGLEWOOD FIRE COMPLEX',
#  'OPHIR FIRE',
#  'EASTERN OKLAHOMA COUNTY FIRE COMPLEX',
#  'SEVERE STORMS, HAIL, FLOODING AND TORNADOES',
#  'TROPICAL STORM CINDY',
#  'ICE JAMS & FLOODING',
#  'BROOKSIDE FIRE',
#  'HOLIDAY BEACH FIRE',
#  'SAPULPA FIRE COMPLEX',
#  'BRECKENRIDGE FIRE',
#  'ROMERO FIRE',
#  'BURR OAK FIRE',
#  'APPLEGATE FIRE',
#  'TROPICAL DEPRESSION ERNESTO, SEVERE STORMS AND FLOODING',
#  'SHUMACH FIRE COMPLEX',
#  'TROPICAL STORM HENRI',
#  'SEVERE STORM, HIGH TIDES & FLOODING',
#  'SEVERE STORMS AND TORNADO',
#  'ROACH FIRE',
#  'FLOODING & LANDSLIDES',
#  'OAKLAND HILLS FIRE',
#  'NV - VOLTAIRE-2 FIRE - 09-29-2003',
#  'TYPHOON LOUISE',
#  'EXTREME WEATHER CONDITONS AND FLOODING',
#  'REIMER FIRE',
#  'TX - STANLEY MAINLINE FIRE - 09/04/00',
#  'STORM & FLOOD',
#  'COUNTRY CLUB FIRE',
#  'HURRICANE FRAN',
#  'HEAVY RAINS, SNOWMELT AND FLOODING',
#  'SEVERE STORMS, A TORNADO, AND FLOODING',
#  'CASCADE FIRE',
#  'IRON MOUNTAIN FIRE',
#  'QUINLAN FIRE',
#  'HAWAII COUNTY FIRE COMPLEX',
#  'MULHALL FIRE',
#  'EXTREME WILDFIRE THREAT',
#  '53 BIG PINE FIRE',
#  "BOB'S TRAIL FIRE",
#  'STORMS, FLOOD, MUDSLIDES & TORNADOES',
#  'SEVERE STORMS, TORNADOES, HAIL & FLOODS',
#  'SEVERE STORMS, HIGH WINDS, TORNADOES, AND FLOODING',
#  'CAUGHLIN FIRE',
#  'SANTIAGO FIRE',
#  'HURRICANE MATTHEW',
#  'TWIN LAKES FIRE COMPLEX',
#  'HURRICANE HILDA',
#  'CONTACT FIRE',
#  'RAINS, SHOWMELT, STORMS & FLOODING',
#  'HURRICANE DORA',
#  'POWERLINE FIRE',
#  'HURRICANE GUSTAV',
#  'RHEA FIRE COMPLEX',
#  'CROWN FIRE',
#  'MIDWEST CITY FIRE COMPLEX',
#  'LA PORTE FIRE',
#  'MT - WILLIE FIRE',
#  'WIND STORM',
#  'DESHKA LANDING FIRE',
#  'HENRYS CREEK FIRE',
#  'CA-VERDALE FIRE 10-25-2003',
#  'MATT LOOP FIRE',
#  'HORSETHIEF BUTTE FIRE',
#  '63RD STREET FIRE',
#  'DALBY SPRINGS FIRE',
#  'SQUIRREL FIRE',
#  'ELK FIRE',
#  'PAWNEE FIRE',
#  'RAIN, FLOODING, MUDSLIDE',
#  'STEVENS COUNTY FIRE COMPLEX',
#  'TROPICAL STORM JEANNE',
#  'SLIDE CREEK WILDFIRE',
#  'HURRICANE LENNY',
#  'BROUGHTON FIRE',
#  'SEVERE STORMS, MUDSLIDES & FLOODING',
#  'REESE CREEK FIRE',
#  'WOOD HOLLOW FIRE',
#  'WATER SHORTAGE',
#  'CADDO II FIRE COMPLEX',
#  'THUNDERSTORMS, HAIL & FLOODING',
#  'RECORD/NEAR RECORD SNOW',
#  'SEVERE ICE STORMS, FLOODING',
#  'TROPICAL STORM RITA',
#  'GAGE HOLLAND FIRE',
#  'SOUTH COUNTY FIRE COMPLEX',
#  'NM-BOSQUE FIRE-06-25-2003',
#  'FIRE',
#  'TYPHOON FERN',
#  'RYEGRASS COULEE FIRE',
#  'KY - SOUTHEASTERN DISTRICT FIRE COMPLEX - 11/03/00',
#  'SEVERE STORMS, FLOODING & MUDSLIDES',
#  'SOUTH WOODWARD FIRE',
#  'HURRICANE LENNY MAJOR DECLARATION',
#  'MYRTLE FIRE',
#  'MILL CREEK FIRE',
#  'COASTAL STORM, HIGH TIDES, HEAVY RAIN, & FLOODING',
#  'SEVERE STORMS, TORNADOES, STRAIGHT LINE WINDS, AND FLOODING',
#  'DRY CREEK FIRE COMPLEX',
#  'BLUECUT FIRE',
#  'SEVERE STORMS, FLOODING, TORNADOES, AND STRAIGHT-LINE WINDS',
#  'CAMP BOWIE FIRE',
#  'HURRICANE DONNA',
#  'WY - WINTER STORM  10/5/98',
#  'HIGHWAY 50 FIRE',
#  'KAHANA RIDGE FIRE',
#  'CAVE CREEK FIRE COMPLEX',
#  'HURRICANE MARIA',
#  'OK, TORNADOES 5/3/99',
#  'SEVERE WINTER STORMS, FLOODING, LANDSLIDES,  MUDSLIDES',
#  'UTE PARK FIRE',
#  'FIRES, MUD/LANDSLIDES, FLOODING, SOIL EROSION',
#  'RIVERA MESA FIRE',
#  'TYPHOON YUTU',
#  'DLD FIRE COMPLEX',
#  'CA-LAKEVIEW-07-14-2004',
#  'DEER FIRE',
#  'WILDERNESS RIDGE FIRE',
#  'WILLOW FIRE',
#  'GLENVIEW FIRE',
#  'TX-ALCOA FIRE',
#  'SEVERE FREEZING WEATHER',
#  'SEVERE STORMS, FLOODING, ICE JAMS, SOIL SATURATION',
#  'WAGGONER RANCH FIRE',
#  'SEVERE STORMS, STRAIGHT LINE WINDS, AND TORNADOES',
#  'MISSIONARY RIDGE FIRE',
#  'FL, PERRY FIRE COMPLEX',
#  'SEVERE STORMS, TORNADOES, FLOODING, MUDSLIDES, AND',
#  'HEAVY RAINS, HIGH WINDS, HAIL & TORNADOES',
#  'PARTRICK FIRE',
#  'FLICK CREEK FIRE',
#  'SIMI FIRE',
#  'ANGEL SPRINGS FIRE',
#  '89 EAST FIRE',
#  'FOREST FIRES',
#  'WA-FISCHER WILDFIRE-08-11-2004',
#  'PONCA CITY FIRE',
#  'URBAN FIRE',
#  'KY - EASTERN FIRE COMPLEX - 11/02/2001',
#  'SQUIRREL CREEK FIRE',
#  'HIGH WINDS, TIDAL SURGE & COASTAL FLOODING',
#  'NV - TEN MILE FIRE - 07/05/2001',
#  'HURRICANE FRAN AND ASSOCIATED HEAVY RAINS,FLOODING HIGHWIND',
#  'SEVERE STORMS, FLOODING, AND STRAIGHT-LINE WINDS',
#  'SEVERE STORMS, FLOODING, STRAIGHT-LINE WINDS, AND TORNADOES',
#  'FL - LAKELAND COMPLEX FIRE',
#  'TYPHOON JEAN',
#  'CASHION FIRE COMPLEX',
#  'HURRICANE FRAN AND ASSOCIATED SEVERE STORM COND',
#  'HOHERTZ FIRE',
#  'OK-OAKCLIFF FIRE COMPLEX-9/21/00',
#  'VOLCANIC ERUPTION, MT. ST. HELENS',
#  'FLOWERS-MYAKKA FIRE COMPLEX',
#  'WALLOW FIRE',
#  'WELLESLEY FIRE',
#  'SEVERE WINTER STORM AND EXTREME COLD TEMPERATURES',
#  'COWICHE MILLS FIRE',
#  'SD SKYLINE #2 FIRE 7/16/05',
#  'SEVERE STORM, TORNADO, AND FLOODING',
#  'MUD LAKE FIRE',
#  'TX - QUAIL RUN FIRE - 10/03/00',
#  'PARKER FIRE',
#  'TYPHOON & HIGH TIDES',
#  'HIGH WINDS, TORNADOES & FLOODING',
#  'SADDLE FIRE',
#  'TYPHOONS PAMELA & THERESE',
#  'TC OLAF, INCLUD. HIGH WINDS AND SURF AND HEAVY RAINFALL',
#  'PV FIRE',
#  'SEVERE WINTER STORMS AND AVALANCHES',
#  'HURRICANE GEORGES (DIRECT FEDERAL ASSIST FIRST 72 HRS)',
#  'NINE MILE FIRE',
#  'QUAIL RIDGE FIRE',
#  'RHODES RANCH FIRE',
#  'SEVERE STORMS, HEAVY RAIN, FLASH FLOODS, FLOODING, MUDSLIDES',
#  'MUDSLIDES',
#  'SEVERE WINTER STORMS, FLOODING, COASTAL EROSION AND TIDAL SURGE',
#  'EARTHQUAKE,TSUNAMI, AND FLOODING',
#  'NEW ARCHER FIRE',
#  'SEVERE STORMS, FLOODING, & TORNADOES',
#  'HURRICANE CELIA',
#  'DAHL FIRE',
#  'FREEDOM FIRE',
#  'GOVERNMENT FLATS FIRE COMPLEX',
#  'SESNON FIRE',
#  '63RD AND SOONER ROAD FIRE',
#  'TOXIC ALGAE IN COASTAL WATERS',
#  'HURRICANE GEORGES - TEXAS',
#  'SEVERE THUNDERSTORMS, WINDS, FLOODING, TORNADOES, AND HEAT',
#  'SEVERE STORMS, TORNADOES, HAIL, FLOODING',
#  'NV - GATE FIRE COMPLEX - 07/15/02',
#  'LA TUNA FIRE',
#  'GOODYEAR PLANT FIRE',
#  'WA-NEEDLE FIRE-09-06-2003',
#  'MN - CARLOS EDGE FIRE COMPLEX - 10/19/2000',
#  'DEBRUCE GRAIN ELEVATOR EXPLOSION  (SEDGWICK CTY)',
#  'CA-CROWN WILDFIRE-07-21-2004',
#  'LILAC FIRE',
#  'CHATEAU FIRE',
#  'FREEZE',
#  'TROPICAL DEPRESSION IVAN',
#  'CASA FIRE',
#  'HURRICANE GEORGES/TS FRANCES',
#  'SEVERE WINTER STORMS, FLOODING AND TORNADOES',
#  'SOUTHEASTERN KENTUCKY FIRE COMPLEX',
#  'SEVERE FLOODING,SEVERE WINTER STORMS, SNOWMELT, SPRING RAINS',
#  'LOMA PRIETA EARTHQUAKE',
#  'SEVERE WINTER STORM, RECORD/NEAR RECORD SNOW, HEAVY RAINS, FLOODING AND LANDSLIDES',
#  'KING FIRE',
#  'SEVERE WINTER STORMS',
#  'ROCKHOUSE FIRE',
#  'CA-RAILROAD FIRE-07-03-2003',
#  'HURRICANE CARLA',
#  'SEVERE STORMS, FLOODING & TORNADOES',
#  'SEVERE WINTER STORM, SNOWSTORM, AND FLOODING',
#  'SEVERE STORMS, STRAIGHT-LINE WINDS, AND TORNADOES',
#  'VELMA FIRE COMPLEX',
#  'HURRICANE LANE',
#  'KLAMATHON FIRE',
#  'SEVERE SNOWFALL, WINTER STORM',
#  'LA BARRANCA FIRE',
#  'TROPICAL STORM HALONG',
#  'STEEL FIRE',
#  'NORTH FIRE',
#  'MILE POST 97 FIRE',
#  'AZ-RYAN-WILDFIRE-4/30/2002',
#  'SHULTZ FIRE',
#  'MT-SOUTHWESTERN ZONE TWO FIRE COMPLEX',
#  'HURRICANE & FLOODS',
#  'SEVERE STORMS, FLOODING, & LANDSLIDES',
#  'BOYKEN ROAD FIRE',
#  'MOCCASIN HILLS FIRE',
#  'FLOODNG (NYS BARGE CANAL)',
#  'MAREK FIRE',
#  'INYO FIRE COMPLEX',
#  'LAVA MOUNTAIN FIRE',
#  'LOCKHEED FIRE',
#  'AKAWANA FIRE',
#  'FLOODING, LANDSLIDES, AND MUDSLIDES',
#  'GUTHRIE FIRE',
#  'SEVERE THUNDERSTORMS, HIGH WINDS,RAIN, FLOODING',
#  'ELECTRA WEST FIRE',
#  'SEVERE WINTER STORMS, FREEZING, FLOODING',
#  'CA - SAWMILL FIRE - 06-27-2003',
#  'TSUNAMI WAVE SURGE',
#  'COPPER BREAKS FIRE',
#  'SEVERE SNOWSTORMS',
#  'MONTAGUE FIRE COMPLEX',
#  'MOOSE MOUNTAIN FIRE',
#  'LIZARD FIRE',
#  'SEVERE HARDSHIP',
#  'SOUTH ODESSA FIRE',
#  'SEVERE ICE STORMS, RAIN, HIGH WINDS AND FLOODING',
#  'HIGH SURF AND WAVE ACTION',
#  'ANDERSON ROAD FIRE',
#  'OAK GROVE FIRE',
#  'CO - SNAKING FIRE - 4/23/2002',
#  'HIGHWAY 141 FIRE COMPLEX',
#  'SEVERE WINTER STORMS, LAND & MUDS SLIDES,FLOODING',
#  'HIGH WINDS, HEAVY RAINS & TORNADOES',
#  'TYPHOON ORCHID',
#  'DYER MILL FIRE',
#  'COLOCKUM TARPS FIRE',
#  'TX - MESQUITE CREEK FIRE - 09/08/00',
#  'HURRICANE ISABEL',
#  'FLOODING, HIGH WINDS, AND WIND DRIVEN RAIN',
#  'POINSETTIA FIRE',
#  'HURRICANE FLORENCE',
#  'BADGER MOUNTAIN FIRE COMPLEX',
#  'BUCKWEED FIRE',
#  'TX - LIVE OAK LOOP FIRE',
#  'NV - ANTELOPE FIRE - 08/09/2001',
#  'WASHOE FIRE',
#  'WEST MIMS FIRE',
#  'THE EL NINO (THE SALMON INDUSTRY)',
#  'ICE JAM & FLOODING',
#  'FLOODING, HIGH SURF, HIGH WINDS, AND WIND-DRIVEN RAIN ASSOCIATED W TYPH TINGTING',
#  'HENRYETTA FIRE',
#  'SEVERE WINDS AND FLOODING ASSOC WITH HURRICANE FRAN',
#  'WA STORMS & FLOODING 5/26/98',
#  'SOUTH WARD GAP FIRE',
#  'WV - TROUGH AND SMOKE HOLE FIRE COMPLEX - 11/16/2001',
#  '30TH AVENUE FIRE',
#  'OR - SQUIRE PEAK/WALL CREEK FIRE - 07/17/02',
#  'CA - COPPER FIRE - 06-06-2002',
#  'WILDFIRES, FLOODING, MUDFLOW AND DEBRIS FLOW DIRECTLY RELATED T',
#  'SEVERE STORMS, FLOODING',
#  'NORTH TRINITY FIRE',
#  'OLOWALU FIRE',
#  'TUNK GRADE FIRE',
#  'OR-WYETH/HERMAN CREEK FIRE 09-02-2003',
#  'CA-GEYSERS FIRE-09-04-2004',
#  'EASY FIRE',
#  'TYPHOON MITAG',
#  'SEVERE STORMS, TORNADOES, STRAIGHT-LINE WINDS, FLOODING, AND LANDSLIDES',
#  '101 RANCH FIRE',
#  'FLOOD & EROSION',
#  'STORMS, TORNADOES, FLOODS',
#  'EXPLOSION',
#  'SEVERE WINTER STORM, FLOODING, LANDSLIDES, AND MUDSLIDES',
#  'FISHEL CREEK FIRE COMPLEX',
#  'SEVERE STORMS, STRAIGHT-LINE WINDS, FLOODING, LANDSLIDES, AND MUDSLIDES',
#  'HEAVY RAIN & HIGH WINDS',
#  'SEVERE STORMS, TORNADOES, STRAIGHT-LINE WINDS AND',
#  'TROPICAL STORM ROY',
#  'SLEEPY HOLLOW FIRE',
#  'MN - BY-PASS FIRE - 05/31/2002',
#  'NV - GONDOLA FIRE - 07/03/2002',
#  'SEVERE STORMS, FLOODING, TORNADOES & STRAIGHT-LINE',
#  'HURRICANE JUAN',
#  'TN-GREENEVILLE FIRE COMPLEX-11/03/00',
#  'STEINER RANCH FIRE',
#  'TX-DEEP CREEK FIRE-9/8/00',
#  'ELAN CHURCH ROAD FIRE',
#  'HEAVY RAINS, TORNADOES & FLOODING',
#  'CATHEDRAL FIRE',
#  'SEVERE WINTER STORMS, FLOODING, AND ICE JAMS',
#  'TYPHOON MARIE',
#  'NM-TURKEY FIRE-6-2-02',
#  'CARLTON COMPLEX FIRE',
#  'SEVERE ICE STORM, RAINS AND HIGH WINDS',
#  'SEVERE STORMS & EXTENSIVE FLOODING',
#  'BIG ROCK FIRE',
#  'FRANKHOMA 81-FIRE',
#  'CADDO FIRE',
#  'CRANSTON FIRE',
#  'PONDEROSA FIRE',
#  'SPRING CREEK FIRE',
#  'CA-CEDAR FIRE-10-26-2003',
#  'SEVERE STORMS, FLOODING, AND A TORNADO',
#  'WINTER COASTAL STORM',
#  'SEVERE STORMS, TORNADOES, FLOODING AND MUDSLIDES',
#  'TYPHOON SALLY',
#  'SEVERE STORMS, HIGH WINDS & HIGH TIDES',
#  '265TH WEST FIRE',
#  'SEVERE STORMS, FLOODING AND MUDSLIDES',
#  'TORNADOES, WINDSTORMS & FLOODING',
#  'SEVERE STORMS, FLOODING, HEAVY RAINS, HIGH WINDS',
#  'HURRICANE MICHAEL',
#  'WILLIAMS FIRE',
#  'HURRICANE & SEVERE STORM',
#  'MARIA FIRE',
#  'SEVERE WINTER STORM AND SNOWSTORM',
#  'RINGGOLD FIRE',
#  'HURRICANE, RAIN, WIND, HAIL & FLOODS',
#  'SEVERE STORMS  AND HIGH WINDS',
#  'BLIZZARD & SNOWSTORMS',
#  'SEVERE STORMS, FLOODING, TORNADO, AND STRAIGHT-LIN',
#  'HASKELL COUNTY FIRE',
#  'EGLEY FIRE COMPLEX',
#  'BLIZZARDS, SEVERE WINDS & SNOWFALL, COASTAL STORM',
#  '1148 FIRE',
#  'STRAWBERRY FIRE',
#  'CLAY SPRINGS FIRE',
#  'OASIS PIPELINE FIRE',
#  'FLIPPERS BEND FIRE',
#  'GOOSE FIRE',
#  'CO - ELDORADO FIRE',
#  'ANACONDA FIRE',
#  'RAIN, WINDS, & TORNADOES',
#  'EXTREME FIRE HAZARDS',
#  'COCOS FIRE',
#  'WINTER STORM & COASTAL FLOODING',
#  'HICKMAN FIRE',
#  'SWEAT FARM AGAIN FIRE',
#  'SEVERE STORMS, HAIL, FLOODING, AND TORNADOES',
#  'LEVEE BREAK & FLOODING',
#  'SEVERE WINTER STORM, RECORD AND NEAR RECORD SNOW',
#  'PARK ROAD FIRE',
#  'WEST FIRE',
#  'WA-BEEBE FIRE-07-04-2004',
#  '617 FIRE',
#  'OR-REDWOOD HIGHWAY WILDFIRE-08-04-2004',
#  'SEVERE WINTER STORMS AND FLOODING',
#  'SIMMONS ROAD FIRE',
#  'WA - MT LEONA FIRE COMPLEX - 2378',
#  'BIG SPRINGS FIRE',
#  'PERRY FIRE COMPLEX',
#  'COUGAR CREEK FIRE',
#  'HURRICANE SANDY',
#  'CO - BURN CANYON FIRE - 07/15/02',
#  'SEAWAVE ACTION & FLOODING',
#  'ROSE CREST FIRE',
#  'SEVERE STORMS, FLOODING, AND GROUND SATURATION',
#  'MILFORD FLAT FIRE',
#  'THREAT OF FLOODING AT SPIRIT LAKE',
#  'EAST ZONE FIRE COMPLEX',
#  'ALICE CREEK FIRE',
#  'DROUGHT, CROP LOSSES',
#  'LITTLE GOOSE FIRE',
#  'FLAGPOLE FIRE COMPLEX',
#  'CA - WILDFIRE (PACIFIC FIRE) - 01-06-2003',
#  'BUTTE FIRE',
#  'DEER CREEK FIRE',
#  'SEVERE WINTER WEATHER',
#  'RESERVOIR ROAD FIRE',
#  'GRASS, WILDLANDS, & FOREST FIRES',
#  'FIRE DURING A PERIOD OF CIVIL UNREST',
#  'NM-BERNARDO FIRE-6-18-2004',
#  'SCURRY FIRE COMPLEX',
#  'ROCKPORT FIVE FIRE',
#  'KAUNAKAKAI FIRE',
#  'HURRICANE MARILYN',
#  'UT - MOLLIE FIRE - 08/19/01',
#  'TROPICAL STORM DANIELLE',
#  'GOODWIN FIRE',
#  'HURRICANE BERTHA',
#  'SMITH MOUNTAIN FIRE COMPLEX',
#  'TORNADOES, FLOODING, HIGH WINDS & TIDES, FREEZING',
#  'REGENCY FIRE',
#  'JESUSITA FIRE',
#  'SEVERE WINTER STORMS AND BLIZZARD CONDITIONS',
#  'SKIRBALL FIRE',
#  'TX-CHICKEN FIRE-0823-00',
#  'SEVERE STORMS, SNOWMELT, LAND/MUD SLIDES, FLOODING',
#  'SEISMIC SEA WAVE',
#  'HURRICANE FLOYD EMERGENCY DECLARATIONS',
#  'INDIAN CREEK FIRE',
#  'SEVERE STORMS, FLOODING, MUD AND ROCK SLIDES, AND TORNADOES',
#  'SEVERE STORMS/TORNADOS',
#  'ROCKY FIRE',
#  'FLOODING, SEVERE STORMS',
#  'SULPHUR FIRE',
#  'BROADWAY FIRE',
#  'VEKOL FIRE-05-26-2005',
#  'SEVERE WINTER STORM AND FLOODING',
#  '1ST CANYON FIRE',
#  'SEVERE STORMS, FLOODING, LANDSLIDES, AND MUDSLIDES',
#  'MAGIC CITY FIRE',
#  'STORMS & FLASH FLOODING',
#  'ICE JAM AND FLOODING',
#  'TROPICAL STORM GITA',
#  'SEVERE ICE STORM',
#  'GRAHAM FIRE',
#  'EXCESSIVE RAINFALL, HIGH WINDS, AND FLOODING',
#  'TYPHOON NABI',
#  'FREEWAY FIRE COMPLEX',
#  'MILLI 0843 CS FIRE',
#  'ANTONIO FIRE',
#  'TORNADOES, TORRENTIAL RAIN & FLOODING',
#  'SEVERE STORMS, FLOODING, AND LANDSLIDES',
#  'CEMENT MOUNTAIN FIRE',
#  'STICKPIN FIRE',
#  'RECORD SNOW AND NEAR RECORD SNOW',
#  'KY,  WILDFIRES #001',
#  'TROPICAL STORM ISELLE',
#  'SEVERE STORMS, FLOODING, AND ICE JAMS',
#  'HURRICANE OPHELIA',
#  'FLOODS & TORNADOES',
#  'COALINGA EARTHQUAKE',
#  'YUBA FIRE',
#  'BUTTS FIRE',
#  'AZ - ORACLE HILLS FIRE - 07/14/2002',
#  'CA-FRENCH FIRE 08-14-2004',
#  'OIL CREEK FIRE',
#  'HURRICANE EMILY',
#  'BLUE SPRINGS FIRE',
#  'CLAYTON FIRE',
#  'CHIMNEY TOP FIRE',
#  'MUDD FIRE',
#  'NM-PONIL FIRE-06/02/02',
#  'BLACK FOREST WILDFIRE',
#  'MASON FIRE',
#  'SEVERE STORMS AND FLOODING ASSOCIATED WITH HURRICANE IKE',
#  'ND - AGAIN FIRE - 06/29/2002',
#  'SEVERE WINTER STORM AND RECORD AND NEAR RECORD SNOW',
#  'ROBBERS FIRE',
#  'TYPHOON HAGIBIS',
#  'HIDDEN PINES FIRE',
#  'AL - RUSSELLVILLE FIRE - 09/18/99',
#  'SEVERE SNOWFALL & WINTER STORM',
#  'HOLBROOK FIRE',
#  'WA-MIDDLE FORK FIRE-07-12-2003',
#  'AZ - CHEDISKI FARMS FIRE - 06/21/2002',
#  'EIGHTY-TWO FIRE',
#  'SEVERE STORMS, FLOODING, & GROUND SATURATION',
#  'ARABELLA FIRE',
#  'TROPICAL STORM ALLISON',
#  'MUSEUM FIRE',
#  'DAM FAILURE',
#  'NIEDERWALD FIRE',
#  'WARREN GROVE FIRE',
#  'HURRICANE KATRINA EVACUEES',
#  '141ST FIRE',
#  'HEAVY RAINSTORMS & FLOOD',
#  'ENMIN FIRE',
#  'LODGEPOLE FIRE COMPLEX',
#  'KAWAIHAE ROAD FIRE HAWAII',
#  'KS-FLOODING  10/31/98',
#  'SEVERE STORMS, TORNADOES, FLOODING, AND MUDSLIDES',
#  'SEVERE WINTER STORMS, HIGH WINDS, AND FLOODING',
#  'LEHIGH ACRES (ANNA AVE. N.) FIRE',
#  'TORNADOES, FLOODING, SEVERE STORMS, AND HIGH WINDS',
#  'CA-QUARTZ FIRE-7-25-2005',
#  'HEBBRONVILLE FIRE',
#  'SEVERE STORMS AND FLOODING ASSOC WITH TROPICAL STORM FRAN',
#  'TROPICAL STORM ALEX',
#  'SEVERE WINTER STORMS, ICE AND FLOODING',
#  'SEVERE STORMS, WINTER STORMS, TORNADOES AND FLOODING',
#  'HURRICANE WILMA',
#  'SIOUX COUNTY FIRE COMPLEX',
#  'WY - COMMISSARY RIDGE FIRE - 08/31/02',
#  'TRIGO FIRE',
#  'CAPE HORN FIRE',
#  'WI-FLOOD-07/20/99',
#  'SEVERE WINTER ICE STORM,FLASH FLOODING',
#  'MCDANNALD FIRE',
#  'MT-MISSOULA/MINERAL FIRE ZONE-08/08/03',
#  'TROPICAL STORM CHARLEY',
#  'PINNACLE FIRE',
#  'HORSESHOE FIRE',
#  'WINDS, FLOODING, MUDSLIDES',
#  'MALPAIS FIRE',
#  'VIRGINIA TROPICAL STORM DENNIS 08/27/99',
#  'LOSS OF SPACE SHUTTLE COLUMBIA',
#  'CA - MATAGUAY FIRE - 7-13-2004',
#  'PREACHER FIRE',
#  'SEVERE STORMS AND TORNADOES',
#  'SILVER HEELS FIRE',
#  'TROPICAL STORM HANNA',
#  'SEVERE STORMS,FLASH FLOODS',
#  'HURRICANE DAVID, TROPICAL STORM FREDERIC',
#  'SEVERE DEEP FREEZE',
#  'ASPEN FIRE',
#  'FISH FIRE',
#  'SEVERE THUNDERSTORMS AND FLOODING',
#  'CROY FIRE',
#  'PK WEST FIRE',
#  'STORMS, ICE JAMS, SNOWMELT & FLOODING',
#  'WICHITA FIRE COMPLEX',
#  'MIRA LOMA FIRE',
#  'SEVERE WINTER STORMS AND SNOWSTORM',
#  'YARNELL HILL FIRE',
#  'CO-CLOUDY PASS FIRE-07/25/2003',
#  'TROPICAL STORM LEE',
#  'FL00DING, SNOW MELT',
#  'CABAZON FIRE',
#  'ELLSWORTH-LINCOLN-RUSSELL FIRE COMPLEX',
#  'SAWTOOTH FIRE',
#  'PILOT FIRE',
#  'TORNADOES, FLOODING HIGH WINDS',
#  'MILE POST 10 FIRE',
#  'SEVERE STORMS, FLOODING, AND TORNADOES',
#  'SEVERE STORMS & FLASH FLOODING',
#  'IN-WINTER STORM 12/23/98',
#  'HUNGRY VALLEY FIRE',
#  'SAWTOOTH FIRE COMPLEX',
#  'OKEECHOBEE FIRE COMPLEX',
#  'KNEEKNOCKER SWAMP FIRE',
#  'CO - OVERLAND WILDFIRE - 10/29/2003',
#  'CHEVRON FIRE',
#  'MT-ROBERT FIRE-07-23-03',
#  'CARD STREET FIRE',
#  'PROLONGED AND HEAVY RAINS, HIGH SURF,FLOODING,LAND/MUD SLIDE',
#  'TROPICAL STORM IMELDA',
#  'HURRICANE OPAL',
#  'HEAVY RAINS, TORNADOES & FLASH FLOODS',
#  'LOCKHART FIRE',
#  'BOUNDARY FIRE',
#  'TYPHOON IWA',
#  'SEVERE STORM & FREEZING',
#  'SEVERE WINTER STORMS, FLOODING LANDSLIDES, MUD FLOW',
#  'GW FIRE',
#  'RECORD AND/OR NEAR RECORD SNOW',
#  'CA-WILDFIRES-08/25/1999',
#  'WATER WHEEL FIRE',
#  'CRYSTAL FIRE',
#  'SAND FIRE',
#  'CALLAHAN COUNTY FIRE',
#  'SEVERE ICE STORMS, RAINS AND HIGH WINDS',
#  'VALLEY FIRE AND BUTTE FIRE',
#  'TORNADOES & FLOODING',
#  'CA-CERRITOS FIRE-5-04-2004',
#  'HURRICANE GEORGES',
#  'SEVERE WINTER STORMS, FLOODING, LANDSLIDES, AND MUDSLIDES',
#  'MANTON FIRE',
#  'COASTAL STORMS, FLOODS, SLIDES & TORNADOES',
#  'EXTREME RAINFALL AND FLOODING',
#  'FRONTAGE FIRE',
#  'SEVERE WINTER AND ICE STORM',
#  'RAILROAD FIRE',
#  "TS CHATA'AN, INC FLOODING, MUDSLIDES AND LANDSLIDES",
#  'FALLS FIRE',
#  'TROPICAL STORM JEANNE AND RESULTING LANDSLIDES AND MUDSLIDES',
#  'SEVERE STORMS, ICE JAMS & FLOODING',
#  "SEVERE STORMS AND FLOODING ASSOC W TD IDA & NOR'EASTER",
#  'SD - MILL ROAD WILDFIRE - 11/19/2003',
#  'HURRICANE BELLE',
#  'ELK HEIGHTS FIRE',
#  'SEVERE STORMS, FLOODING,HIGH WINDS, ASSOC WITH HURR DANNY',
#  'TRES LAGUNAS FIRE',
#  'TX-TROPICAL STORM ALLISON-06-06-2001',
#  'HARVEYTOWN FIRE',
#  '46 FIRE',
#  'EXPLOSIONS AND FIRE',
#  'BOX ELDER FIRE',
#  'OR-COVE ROAD FIRE-09-05-2003',
#  'TORNADOES AND FLOODING',
#  'SUWANNEE FIRE COMPLEX',
#  'SEVERE STORMS, TORNADOES & FLOODING',
#  'OIL WELL FIRE',
#  'CHETCO BAR FIRE',
#  'TOPANGA FIRE',
#  'LUTHER FIRE',
#  'MCCLAIN COUNTY FIRE',
#  'HI - WAIKOLOA VILLAGE FIRE - 05/18/2003',
#  'TROPICAL STORM DEBBY',
#  'TICK FIRE',
#  'FLOODING',
#  'LITTLE BEAR FIRE',
#  'FLOODING AND MUDSLIDES',
#  'HOLY FIRE',
#  'GOODELL FIRE',
#  'FLOODING FROM RAINS & SNOWMELT',
#  'REMNANTS OF TROPICAL STORM LEE',
#  'SEVERE STORM AND SNOWSTORM',
#  'TYPHOON BUALOI',
#  'FLOODING, MUDSLIDES & LANDSLIDES',
#  'TYPHOON ROY',
#  'HIGH WINDS, HEAVY RAINS & FLOODING',
#  'AZ-BOBBY FIRE-06-08-2005',
#  'SEVERE STORMS, FLOODING, MUDSLIDES, AND LANDSLIDES',
#  'DAM COLLAPSE, FLOODING',
#  'SEVERE STORMS, FLOODING, SNOW MELT, AND ICE JAMS',
#  'GAVILAN FIRE',
#  'LOSS OF THE SPACE SHUTTLE COLUMBIA',
#  'HURRICANE BOB & SEVERE STORMS',
#  'SEVERE STORMS, STRAIGHT-LINE WINDS, TORNADOES, FLOODING,LANDSLIDES,AND MUDSLIDES',
#  'CLEVELAND-MANNFORD FIRE COMPLEX',
#  'SEVERE STORMS, TORNADOES, FLOODING, MUDSLIDES, AND LANDSLIDES',
#  'REDWOOD VALLEY FIRE',
#  'AL - JACKSON FARMS FIRE - 09/18/99',
#  'SEVERE FOREST FIRE',
#  'ISLAND FIRE',
#  'GOLD CANYON FIRE',
#  'GRASS VALLEY FIRE',
#  '259 FIRE',
#  'BRUSH FIRES',
#  '36 PIT FIRE',
#  'CA-WHITMORE FIRE-10-28-2003',
#  'TROPICAL STORM AGNES',
#  'SUNDEVIL FIRE',
#  'TX - MOORE BRANCH FIRE - 09/03/00',
#  'CLOVER FIRE',
#  'HUGO ROAD FIRE',
#  'HURRICANE FLOYD',
#  'STORM',
#  'SEVERE WINTER STORM, FREEEZING RAIN AND SLEET',
#  'SEVERE STORMS AND TORNADOES, AND FLOODING',
#  'NORTHRIDGE EARTHQUAKE',
#  'HURRICANE FRANCES',
#  '335 FIRE',
#  'HURRICANE HORTENSE',
#  'BREVARD FIRE COMPLEX',
#  'VA - HEARD MOUNTAIN FIRE COMPLEX - 11/20/2001',
#  'BOBCAT GULCH FIRE',
#  'OR - CACHE MOUNTAIN FIRE - 07/28/02',
#  'SEVERE THUNDERSTORMS',
#  'NV - FLASH FLOODING 7/8/99',
#  'CORNET AND WINDY RIDGE FIRE COMPLEX',
#  'COUNTY LINE FIRE',
#  'CLEVELAND FIRE',
#  'OR  BRIDGE CREEK FIRES 2375',
#  'CHLORINE BARGE ACCIDENT',
#  'SD RICCO FIRE',
#  'UPRIVER BEACON FIRE',
#  'TROPICAL STORM ALBERTO',
#  'NM-LA CUEVA FIRE',
#  'MARTIN FIRE',
#  'UPPER COLONY FIRE',
#  'HURRICANE JEANNE',
#  'HURRICANE CARMEN',
#  'WA - VIRGINIA LAKES COMPLEX - 2372',
#  'POWER OUTAGE',
#  'SEVERE STORMS, TORNADOES, STRAIGHT-LINE WINDS, AND ASSOCIATED FLOODING',
#  'TX-PINE COVE FIRE-9/18/00',
#  ...}

# %%
dis.loc[:,['incidentType','declaredCountyArea','placeCode']].dropna() #droping data points we don't have enough information to scrape for
# Out:
#       incidentType         declaredCountyArea  placeCode
# 83           Flood              Clay (County)    99021.0
# 163          Flood            Alpine (County)    99003.0
# 176          Flood            Colusa (County)    99011.0
# 181          Flood             Butte (County)    99007.0
# 182          Flood         Del Norte (County)    99015.0
# ...            ...                        ...        ...
# 51011   Earthquake  Sabana Grande (Municipio)    99121.0
# 51012   Earthquake     Juana Diaz (Municipio)    99075.0
# 51013   Earthquake       Mayaguez (Municipio)    99097.0
# 51014   Earthquake    Hormigueros (Municipio)    99067.0
# 51015   Earthquake        Arecibo (Municipio)    99013.0
#
# [50802 rows x 3 columns]

# %%
category_id = 'BNeawe s3v9rd AP7Wnd' # This is the id google uses for the text we want to scrape

# %%
val_id = 'BNeawe tAd8D AP7Wnd' # This is the id google uses for values we want

# %%
# This class scrapes all the info you get back from a google search and parses the html to -
# Give us back the values we need to build a dataset
class Analysis:
    def __init__(self, term):
        self.term = term
        self.date = None
        self.death = None
        self.damage = None
        self.location = None
        self.category= None
        self.specs = None
        self.url = f'https://www.google.com/search?q={self.term}&source=lnms'
       
        
    def crawl(self):
        res = requests.get(self.url) # fetching the html and css from googles api
        soup = BeautifulSoup(res.text, 'html.parser') #html.parser
        if len(soup.find_all('span',category_id)) > 1:
            a = [i.text for i in soup.find_all('span',category_id)]
            b = [i.text for i in soup.find_all('span',val_id)]
            disaster_specs = {a[i]:b[i] for i in range(len(a))}
        # The results we put into if statements to prevent errors from inconsistancies in google searching
            if 'Date' in disaster_specs.keys():
                self.date =  disaster_specs['Date']
            if 'Damage' in disaster_specs.keys():
                self.damage =  disaster_specs['Damage']
            if 'Affected areas' in disaster_specs.keys():
                self.location = disaster_specs['Affected areas']
            if 'Category' in disaster_specs.keys():
                self.category=  disaster_specs['Category']
            if 'Total fatalities' in disaster_specs.keys():
                    self.death = disaster_specs['Total fatalities']
            self.specs = disaster_specs
            if 'Direct fatalities' in disaster_specs.keys():
                self.death = disaster_specs['Direct fatalities']   
t0 = time.time()

# %%
res = requests.get('https://www.google.com/search?q=Hurricane Sandy&source=lnms')

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
soup # This was all a test to figure out what my code is doing.
# Out:
# <!DOCTYPE doctype html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>Hurricane Sandy - Google Search</title><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# var a=window.performance;window.start=(new Date).getTime();a:{var b=window;if(a){var c=a.timing;if(c){var d=c.navigationStart,f=c.responseStart;if(f>d&&f<=window.start){window.start=f;b.wsrt=f-d;break a}}a.now&&(b.wsrt=Math.floor(a.now()))}}window.google=window.google||{};var h=function(g){g&&g.target.setAttribute("data-iml",(new Date).getTime())};document.documentElement.addEventListener("load",h,!0);google.rglh=function(){document.documentElement.removeEventListener("load",h,!0)};}).call(this);(function(){
# var c=[],e=0;window.ping=function(b){-1==b.indexOf("&zx")&&(b+="&zx="+(new Date).getTime());var a=new Image,d=e++;c[d]=a;a.onerror=a.onload=a.onabort=function(){delete c[d]};a.src=b};}).call(this);</script><style>body{margin:0 auto;max-width:736px;padding:0 8px}a{color:#1967D2;text-decoration:none;tap-highlight-color:rgba(0,0,0,.1)}a:visited{color:#4B11A8}a:hover{text-decoration:underline}img{border:0}html{font-family:Roboto,HelveticaNeue,Arial,sans-serif;font-size:14px;line-height:20px;text-size-adjust:100%;color:#3C4043;word-wrap:break-word;background-color:#fff}.bRsWnc{background-color:#fff;border-top:1px solid #e0e0e0;height:39px;overflow:hidden}.N6RWV{height:51px;overflow-scrolling:touch;overflow-x:auto;overflow-y:hidden}.Uv67qb{box-pack:justify;font-size:12px;line-height:37px;justify-content:space-between;justify-content:space-between}.Uv67qb a,.Uv67qb span{color:#757575;display:block;flex:none;padding:0 16px;text-align:center;text-transform:uppercase;}span.OXXup{border-bottom:2px solid #4285f4;color:#4285f4;font-weight:bold}a.eZt8xd:visited{color:#757575}.FElbsf{border-left:1px solid rgba(0,0,0,.12)}header article{overflow:visible}.Pg70bf{height:39px;display:box;display:flex;display:flex;width:100%}.H0PQec{position:relative;flex:1}.sbc{display:flex;width:100%}.Pg70bf input{margin:2px 4px 2px 8px;}.x{width:26px;color:#757575;font:27px/38px arial, sans-serif;line-height:40px;}#qdClwb{flex:0 0 auto;width:39px;height:39px;border-bottom:0;padding:0;border-top-right-radius:8px;background-color:#3b78e7;border:1px solid #3367d6;background-image:url(...);}.sc{font-size:;position:absolute;top:39px;left:0;right:0;box-shadow:0px 2px 5px rgba(0,0,0,.2);z-index:2;background-color:#fff}.sc>div{padding:10px 10px;padding-left:16px;padding-left:14px;border-top:1px solid #DFE1E5}.scs{background-color:#f5f5f5;}.noHIxc{display:block;font-size:16px;padding:0 0 0 8px;flex:1;height:35px;outline:none;border:none;width:100%;-webkit-tap-highlight-color:rgba(0,0,0,0);overflow:hidden;}.sbc input[type=text]{background:none}.sml .cOl4Id{display:none}.l{display:none}.sml header{background:none}.sml .l{display:block;padding:0 8px}.sml .l{letter-spacing:-1px;text-align:center;border-radius:2px 0 0 0;font:22px/36px Futura, Arial, sans-serif;font-smoothing:antialiased}.bz1lBb{background:#fff;border-radius:8px 8px 0 0;box-shadow:0 1px 6px rgba(32, 33, 36, 0.18);margin-top:10px}.KP7LCb{border-radius:0 0 8px 8px;box-shadow:0 2px 3px rgba(32, 33, 36, 0.18);margin-bottom:10px;overflow:hidden}.cOl4Id{letter-spacing:-1px;text-align:center;font:22pt Futura, Arial, sans-serif;padding:10px 0 5px 0;height:37px;font-smoothing:antialiased}.cOl4Id span{display:inline-block}.S591j{height:100%}.V6gwVd{color:#4285f4}.iWkuvd{color:#ea4335}.cDrQ7{color:#fbcc05}.ntlR9{color:#34a853}.tJ3Myc{-webkit-transform:rotate(-20deg);position:relative;left:-1px;display:inline-block}footer{text-align:center;margin-top:18px}footer a,footer a:visited,.smiUbb{color:#5f6368}.ksTU4c{margin:0 13px}#mCljob{margin-top:36px}#mCljob>div{margin:20px}</style></head><body jsmodel=" TvHxbe"><header id="hdr"><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var c=500;(function(){window.screen&&window.screen.width<=c&&window.screen.height<=c&&document.getElementById("hdr").classList.add("sml");}).call(this);})();</script><div class="cOl4Id"><a href="/?sa=X&amp;ved=0ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a></div><div class="bz1lBb"><form class="Pg70bf" id="sf"><a class="l" href="/?output=search&amp;ie=UTF-8&amp;sa=X&amp;ved=0ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQPAgE"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a><input name="ie" type="hidden" value="ISO-8859-1"/><div class="H0PQec"><div class="s ...
# var a=document.getElementById("st-toggle"),b=document.getElementById("st-card");a&&b&&a.addEventListener("click",function(c){b.style.display=b.style.display?"":"none";c.preventDefault()},!1);}).call(this);</script></div></div><style>.ZINbbc{background-color:#fff;margin-bottom:10px;box-shadow:0 1px 6px rgba(32, 33, 36, 0.28);border-radius:8px}.uUPGi{font-size:14px;line-height:20px;}.O9g5cc>*:first-child{border-top-left-radius:8px;border-top-right-radius:8px}.O9g5cc>*:last-child{border-bottom-left-radius:8px;border-bottom-right-radius:8px}.O9g5cc>.qxDOhb>*:first-child{border-top-left-radius:8px;border-top-right-radius:8px}.O9g5cc>.qxDOhb>*:last-child{border-bottom-left-radius:8px;border-bottom-right-radius:8px}.nGphre{float:right;padding-left:16px}.UykT9d{border-radius:8px;display:block}.nYT7Qb{clear:both}.kCrYT{padding:12px 16px 12px}.BNeawe{white-space:pre-line;word-wrap:break-word}.deIvCb{font-size:16px;line-height:20px;font-weight:400}.deIvCb.HrGdeb{color:rgba(255,255,255,1)}.deIvCb.AP7Wnd{color:#202124}.Xdlr0d{overflow-x:auto;-webkit-overflow-scrolling:touch;margin:0 -8px;padding:16px 0 16px 24px;padding-top:2px;margin-top:-2px;transform:translate3d(0,0,0)}.idg8be{display:table;border-collapse:separate;border-spacing:8px 0;margin:0 -8px;padding-right:16px}.BVG0Nb{display:table-cell;vertical-align:top;background-color:#fff;border-radius:8px;box-shadow:0 1px 6px rgba(32, 33, 36, 0.28);overflow:hidden}a.fdYsqf{color:#4B11A8}.WddBJd{display:block;margin:0 auto}.R0jTRc{vertical-align:middle}.mHhylf{display:table-cell;vertical-align:middle}.WZ5GJf{align-items:center;padding:0 20px;min-width:112px}.qN9Ked,.DXk5Me{margin:0 auto}.DXk5Me{margin-bottom:12px}.Qi9Fd{background:#fff;border:0;border-radius:999px;display:block;height:56px;justify-content:center;width:56px;z-index:0}.Qi9Fd{box-shadow:0 1px 6px rgba(32, 33, 36, 0.28),inset 0 0 0 0 rgba(0,0,0,0.10),inset 0 0 0 0 rgba(255,255,255,0.50)}.Qi9Fd:focus{outline:none}.Qi9Fd .hWHuJ{display:block;margin:0 auto}.ji5jpf{text-align:center}.tAd8D{font-size:14px;line-height:20px}.tAd8D.HrGdeb{color:rgba(255,255,255,.7)}.tAd8D.AP7Wnd{color:#70757A}.xpc .hwc,.xpx .hwx{display:none}.skVgpb{display:table;table-layout:fixed;width:100%}.VGHMXd{display:table-cell;vertical-align:middle;height:52px;text-align:center}.LpaDrb{margin:0 auto 8px;display:block}.vbShOe{padding-top:0}.x54gtf{height:1px;background-color:#dfe1e5;margin:0 16px}.Q0HXG{height:1px;background-color:#dfe1e5}.Ap5OSd{padding-bottom:12px}.s3v9rd{font-size:14px;line-height:20px}.s3v9rd.HrGdeb{color:rgba(255,255,255,1)}.s3v9rd.AP7Wnd{color:#202124}.XLloXe{color:#1967D2;font-size:14px;line-height:20px}.XLloXe a:visited{color:#4B11A8}.XLloXe.HrGdeb{color:rgba(255,255,255,1)}.XLloXe.HrGdeb a:visited{color:rgba(255,255,255,.7)}.AVsepf{padding-bottom:8px}.AVsepf.u2x1Od{padding-bottom:0}.Ru8idb{margin-top:-16px}.punez{font-weight:700;letter-spacing:0.75px;text-transform:uppercase}.wyrwXc{font-size:12px;line-height:16px}.wyrwXc.HrGdeb{color:rgba(255,255,255,1)}.wyrwXc.AP7Wnd{color:#202124}.EYOsld{display:inline-block;position:relative}.BFi9Zb{overflow:hidden;position:relative}.S7Jdze{align-items:center;display:flex;flex-direction:column;justify-content:space-around}hr{border:0;border-bottom:1px solid #dfe1e5;margin:0;}.BUybKe,.HsnFBf{margin-left:16px}.BUybKe,.oM2GA{margin-right:16px}.XO7rhc{margin:0 -16px}.iIWm4b{box-sizing:border-box;min-height:48px}.fLtXsc{padding:14px;position:relative}.Lym8W{width:14px;height:20px;position:relative;margin:0 auto}.xCgLUe{position:absolute;right:16px;margin-top:-10px;top:50%}.Lym8W div{position:absolute;border-left:7px solid transparent;border-right:7px solid transparent;width:0;height:0;left:0}.IyYaEd{top:7px;border-top:7px solid #757575}.ECUHQe{top:4px;border-top:7px solid #fff}.AeQQub{bottom:7px;border-bottom:7px solid #757575}.YCU7eb{bottom:4px;border-bottom:7px solid #fff}.wITvVb{margin:0;padding:12px 16px 12px}.FCUp0c{font-weight:bold}.LKSyXe{height:1px;background-color:#dfe1e5;margin:0 16px}.NtmAdb{ ...
# <span class="BNeawe"><a href="/url?q=https://en.wikipedia.org/wiki/Effects_of_Hurricane_Sandy_in_New_York&amp;sa=U&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQ0gIwHHoECAcQAg&amp;usg=AOvVaw1y3yJ0hALtOxSq2LN1ElSQ"><span class="XLloXe AP7Wnd">Effects of Hurricane Sandy in ...</span></a></span> · <span class="BNeawe"><a href="/url?q=https://en.wikipedia.org/wiki/Hurricane_Sandy:_Coming_Together&amp;sa=U&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQ0gIwHHoECAcQAw&amp;usg=AOvVaw1xHzGX6SDTupAKJuRzC6iU"><span class="XLloXe AP7Wnd">Hurricane Sandy: Coming ...</span></a></span> · <span class="BNeawe"><a href="/url?q=https://en.wikipedia.org/wiki/Effects_of_Hurricane_Sandy_in_the_Greater_Antilles&amp;sa=U&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQ0gIwHHoECAcQBA&amp;usg=AOvVaw0ZW3KaxownAXJRbX1PEPLt"><span class="XLloXe AP7Wnd">Greater Antilles</span></a></span></div></div></div></div></div></div></div></div><div><div class="ZINbbc xpd O9g5cc uUPGi"><div class="kCrYT"><a href="/url?q=https://www.cnn.com/2013/07/13/world/americas/hurricane-sandy-fast-facts/index.html&amp;sa=U&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQFjAdegQICRAB&amp;usg=AOvVaw1Is51ZsRKAR-HUZcfHJrZu"><div class="BNeawe vvjwJb AP7Wnd">Hurricane Sandy Fast Facts - CNN - CNN.com</div><div class="BNeawe UPmit AP7Wnd">https://www.cnn.com › 2013/07/13 › world › americas › hurricane-sandy-f...</div></a></div><div class="x54gtf"></div><div class="kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd"><div><div><div class="BNeawe s3v9rd AP7Wnd"><span class="r0bn4c rQMQod">Oct 2, 2019</span><span class="r0bn4c rQMQod"> · </span>Read CNN's Fast Facts on Hurricane Sandy. As a hurricane and post-tropical cyclone, Sandy was responsible for 117 deaths in the United ...</div></div></div></div></div></div></div></div><div><div class="ZINbbc xpd O9g5cc uUPGi"><div class="kCrYT"><a href="/url?q=https://www.livescience.com/24380-hurricane-sandy-status-data.html&amp;sa=U&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQFjAeegQIAxAB&amp;usg=AOvVaw0wH61fvNx5z7U1hmfyutvM"><div class="BNeawe vvjwJb AP7Wnd">Hurricane Sandy: Facts &amp; Data | Live Science</div><div class="BNeawe UPmit AP7Wnd">https://www.livescience.com › 24380-hurricane-sandy-status-data</div></a></div><div class="x54gtf"></div><div class="kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd"><div><div><div class="BNeawe s3v9rd AP7Wnd"><span class="r0bn4c rQMQod">Nov 27, 2012</span><span class="r0bn4c rQMQod"> · </span>Tropical Storm Sandy was the 18th named storm of the 2012 Atlantic hurricane season. It was upgraded to a hurricane on Oct. 24 when its maximum sustained winds reached 74 mph (119 kph). Sandy tore through the Caribbean, making landfall at Jamaica on Oct. 24.</div></div></div></div></div></div></div></div><div><div class="ZINbbc xpd O9g5cc uUPGi"><div class="kCrYT"><a href="/url?q=https://www.nasa.gov/mission_pages/hurricanes/archives/2012/h2012_Sandy.html&amp;sa=U&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQFjAfegQIBhAB&amp;usg=AOvVaw0F79grF-Ae8dzvvUH1qoTO"><div class="BNeawe vvjwJb AP7Wnd">Hurricane Sandy (Atlantic Ocean) | NASA</div><div class="BNeawe UPmit AP7Wnd">https://www.nasa.gov › hurricanes › archives › h2012_Sandy</div></a></div><div class="x54gtf"></div><div class="kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd"><div><div><div class="BNeawe s3v9rd AP7Wnd"><span class="r0bn4c rQMQod">Oct 28, 2013</span><span class="r0bn4c rQMQod"> · </span>Take an historic look back at Hurricane Sandy through NASA updates as the storm happened in 2012.</div></div></div></div></div></div></div></div><div><div class="ZINbbc xpd O9g5cc uUPGi"><div class="kCrYT"><a href="/url?q=https://www.weather.gov/okx/HurricaneSandy&amp;sa=U&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQFjAgegQICxAB&amp;usg=AOvVaw2RYOObtN5adFRhC_l2g5Cm"><div class="BNeawe vvjwJb AP7Wnd">Hurricane Sandy - National Weather Service</div><div class="BNeawe UPmit AP7Wnd">https://www.weather.gov › okx › HurricaneSandy</div></a></div><div class="x54gtf"></div><div class="kCrYT"><div><div class="BNeawe s3v9 ...
# Posted: Nov 2, 2012</div></div></div></div></div><div class="rl7ilb"></div></div></div></div><div><div class="ZINbbc xpd O9g5cc uUPGi"><div class="kCrYT"><div class="q4vBJc"></div><span><div class="BNeawe deIvCb AP7Wnd"><span class="FCUp0c rQMQod">Related searches</span></div></span></div><div class="Q0HXG"></div><div class="X7NTVe"><a class="tHmfQe" href="/search?ie=UTF-8&amp;q=hurricane+sandy+damage&amp;sa=X&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQ1QJ6BAgAEAE"><div class="am3QBf"><div><span><div class="BNeawe deIvCb AP7Wnd">hurricane sandy damage</div></span></div></div></a><div class="HBTM6d XS7yGd"><a href="/search?ie=UTF-8&amp;q=hurricane+sandy+damage"><div class="BNeawe mAdjQc uEec3 AP7Wnd">&gt;</div></a></div></div><div class="Q0HXG"></div><div class="X7NTVe"><a class="tHmfQe" href="/search?ie=UTF-8&amp;q=hurricane+sandy+nyc&amp;sa=X&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQ1QJ6BAgAEAI"><div class="am3QBf"><div><span><div class="BNeawe deIvCb AP7Wnd">hurricane sandy nyc</div></span></div></div></a><div class="HBTM6d XS7yGd"><a href="/search?ie=UTF-8&amp;q=hurricane+sandy+nyc"><div class="BNeawe mAdjQc uEec3 AP7Wnd">&gt;</div></a></div></div><div class="Q0HXG"></div><div class="X7NTVe"><a class="tHmfQe" href="/search?ie=UTF-8&amp;q=hurricane+sandy+death+toll&amp;sa=X&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQ1QJ6BAgAEAM"><div class="am3QBf"><div><span><div class="BNeawe deIvCb AP7Wnd">hurricane sandy death toll</div></span></div></div></a><div class="HBTM6d XS7yGd"><a href="/search?ie=UTF-8&amp;q=hurricane+sandy+death+toll"><div class="BNeawe mAdjQc uEec3 AP7Wnd">&gt;</div></a></div></div><div class="Q0HXG"></div><div class="X7NTVe"><a class="tHmfQe" href="/search?ie=UTF-8&amp;q=what+caused+hurricane+sandy&amp;sa=X&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQ1QJ6BAgAEAQ"><div class="am3QBf"><div><span><div class="BNeawe deIvCb AP7Wnd">what caused hurricane sandy</div></span></div></div></a><div class="HBTM6d XS7yGd"><a href="/search?ie=UTF-8&amp;q=what+caused+hurricane+sandy"><div class="BNeawe mAdjQc uEec3 AP7Wnd">&gt;</div></a></div></div><div class="Q0HXG"></div><div class="X7NTVe"><a class="tHmfQe" href="/search?ie=UTF-8&amp;q=hurricane+sandy+map&amp;sa=X&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQ1QJ6BAgAEAU"><div class="am3QBf"><div><span><div class="BNeawe deIvCb AP7Wnd">hurricane sandy map</div></span></div></div></a><div class="HBTM6d XS7yGd"><a href="/search?ie=UTF-8&amp;q=hurricane+sandy+map"><div class="BNeawe mAdjQc uEec3 AP7Wnd">&gt;</div></a></div></div><div class="Q0HXG"></div><div class="X7NTVe"><a class="tHmfQe" href="/search?ie=UTF-8&amp;q=hurricane+sandy+size&amp;sa=X&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQ1QJ6BAgAEAY"><div class="am3QBf"><div><span><div class="BNeawe deIvCb AP7Wnd">hurricane sandy size</div></span></div></div></a><div class="HBTM6d XS7yGd"><a href="/search?ie=UTF-8&amp;q=hurricane+sandy+size"><div class="BNeawe mAdjQc uEec3 AP7Wnd">&gt;</div></a></div></div><div class="Q0HXG"></div><div class="X7NTVe"><a class="tHmfQe" href="/search?ie=UTF-8&amp;q=hurricane+sandy+wind+speed&amp;sa=X&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQ1QJ6BAgAEAc"><div class="am3QBf"><div><span><div class="BNeawe deIvCb AP7Wnd">hurricane sandy wind speed</div></span></div></div></a><div class="HBTM6d XS7yGd"><a href="/search?ie=UTF-8&amp;q=hurricane+sandy+wind+speed"><div class="BNeawe mAdjQc uEec3 AP7Wnd">&gt;</div></a></div></div><div class="Q0HXG"></div><div class="X7NTVe"><a class="tHmfQe" href="/search?ie=UTF-8&amp;q=hurricane+sandy+new+jersey&amp;sa=X&amp;ved=2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQ1QJ6BAgAEAg"><div class="am3QBf"><div><span><div class="BNeawe deIvCb AP7Wnd">hurricane sandy new jersey</div></span></div></div></a><div class="HBTM6d XS7yGd"><a href="/search?ie=UTF-8&amp;q=hurricane+sandy+new+jersey"><div class="BNeawe mAdjQc uEec3 AP7Wnd">&gt;</div></a></div></div></div></div><footer> <div> <div class="ZINbbc xpd O9g5cc uUPGi BmP5tf"><div class="nMymef MUxGbd lyLwlc"><a aria-label="Next page" class="n ...
# var b=this||self,d=/^[\w+/_-]+[=]{0,2}$/,e=null;var f=document.querySelector(".l"),g=document.querySelector("#sf"),k=g.querySelector(".sbc"),l=g.querySelector("[type=text]"),m=g.querySelector("[type=submit]"),n=g.querySelector(".sc"),p=g.querySelector(".x"),q=l.value,r=[],t=-1,u=q,w,x,y;q||(p&&(p.style.display="none"),z(!1));function z(a){if(k.classList.contains("esbc")){var c=k.classList.contains("chsbc"),h=k.classList.contains("rtlsbc");a&&(n.style.display="block",c?(g.style.borderRadius="20px 20px 0 0",n.style.borderBottom="1px solid #DFE1E5",m.style.borderRadius=h?"20px 0 0 0":"0 20px 0 0"):k.style.borderRadius=h?"0 8px 0 0":"8px 0 0 0");a||(n.style.display="none",c?(g.style.borderRadius="20px",n.style.borderBottom="none",m.style.borderRadius=h?"20px 0 0 20px":"0 20px 20px 0"):k.style.borderRadius=h?"0 8px 8px 0":"8px 0 0 8px")}}function A(){g.querySelector("[name=oq]").value=u;g.querySelector("[name=aqs]").value="heirloom-srp."+(0<=t?t:"")+"."+(0<r.length?"0l"+r.length:"")}
# function C(){w=null;if(x){var a="/complete/search?client=heirloom-srp&hl="+hl+"&json=t&callback=hS&q="+encodeURIComponent(x);"undefined"!==typeof ds&&ds&&(a+="&ds="+ds);var c=document.createElement("script");c.src=a;if(null===e)a:{a=b.document;if((a=a.querySelector&&a.querySelector("script[nonce]"))&&(a=a.nonce||a.getAttribute("nonce"))&&d.test(a)){e=a;break a}e=""}(a=e)&&c.setAttribute("nonce",a);document.body.appendChild(c);x=null;w=setTimeout(C,500)}}
# function D(){for(;n.firstChild;)n.removeChild(n.firstChild);r=[];t=-1;z(!1)}function E(){var a=n.querySelector(".scs");a&&(a.className="");0<=t?(a=n.childNodes[t],a.className="scs",q=a.textContent):q=u;l.value=q}l.addEventListener("focus",function(){f&&(f.style.display="none")},!1);l.addEventListener("blur",function(){D();f&&(f.style.display="")},!1);l.addEventListener("keyup",function(a){q=l.value;y=!1;13==a.which?A():27==a.which?(D(),f&&(f.style.display=""),q=u,l.value=q):40==a.which?(t++,t>=r.length&&(t=-1),E()):38==a.which?(t--,-1>t&&(t=r.length-1),E()):(a=q)?(p&&(p.style.display=""),x=a,w||C(),u=a):(p&&(p.style.display="none"),z(!1),D(),u="",y=!0)},!1);m.addEventListener("click",A,!1);p.addEventListener("click",function(){l.value="";p.style.display="none";z(!1)},!1);k.addEventListener("click",function(){l.focus()},!1);window.hS=function(a){if(!y){D();0==a[1].length&&z(!1);for(var c=0;c<a[1].length;c++){var h=a[1][c][0],v=document.createElement("div");v.innerHTML=h;v.addEventListener("mousedown",function(B){B.preventDefault();return!1},!1);h=h.replace(/<\/?b>/g,"");v.addEventListener("click",function(B){return function(){t=B;A();E();D();g.submit()}}(c),!1);n.appendChild(v);z(!0);r.push(h)}}};}).call(this);})();(function(){
# function b(a){for(a=a.target||a.srcElement;a&&"A"!=a.nodeName;)a=a.parentElement;a&&(a.href||"").match(/\/search.*[?&]tbm=isch/)&&(a.href+="&biw="+document.documentElement.clientWidth,a.href+="&bih="+document.documentElement.clientHeight)}document.addEventListener("click",b,!1);document.addEventListener("touchStart",b,!1);}).call(this);</script></div><!-- cctlcm 5 cctlcm --><textarea class="csi" name="csi" style="display:none"></textarea><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var e='ue1OXuu_F-XC3LUP1_GBkAI';var sn='web';(function(){
# function x(a){if(!a||"none"==a.style.display)return 0;if(document.defaultView&&document.defaultView.getComputedStyle){var b=document.defaultView.getComputedStyle(a);if(b&&("hidden"==b.visibility||"0px"==b.height&&"0px"==b.width))return 0}if(!a.getBoundingClientRect)return 1;var c=a.getBoundingClientRect();a=c.left+window.pageXOffset;b=c.top+window.pageYOffset;var f=c.width;c=c.height;var h=0;if(0>=c&&0>=f)return h;0>b+c?h=2:b>=(window.innerHeight||document.documentElement.clientHeight)&&(h=4);if(0>
# a+f||a>=(window.innerWidth||document.documentElement.clientWidth))h|=8;return h||1};var y=e,z=sn,H=[];function I(a,b,c){a="/gen_204?atyp=csi&s="+(z||"web")+"&t="+a+("&lite=1&ei="+y+"&conn="+(window.navigator&&window.navigator.connection?window.navigator.connection.type:-1)+b);b="&rt=";for(var f in c)a+=b+f+"."+c[f],b=",";return a}function J(a){a={prt:a};window.wsrt&&(a.wsrt=window.wsrt);return a}function K(a){window.ping?window.ping(a):(new Image).src=a}
# (function(){for(var a=(new Date).getTime()-window.start,b=J(a),c=0,f=0,h=0,A=document.getElementsByTagName("img"),n="&imn="+A.length+"&biw="+window.innerWidth+"&bih="+window.innerHeight,L=function(g,p){g.onload=function(){f=(new Date).getTime()-window.start;p&&++t==h&&(c=f,B());g.onload=null}},B=function(){n+="&ima="+h;b.aft=c;K(I("aft",n,b))},t=0,M=0,d=void 0;d=A[M++];){var q=x(d),r=1==q;r&&++h;var m=d.hasAttribute("data-ilite"),u=d.hasAttribute("data-deferred")||m,C=d.getAttribute("data-src")||
# d.getAttribute("data-lzysrc");H.push([q,u,!u&&C,google.ldi&&d.id&&google.ldi[d.id]||m&&C]);m=(q=d.complete&&!u)&&Number(d.getAttribute("data-iml"))||0;q&&m?(r&&++t,m&&(d=m-window.start,r&&(c=Math.max(c,d)),f=Math.max(f,d))):L(d,r)}c||(c=a);f||(f=c);t==h&&B();google.rglh&&google.rglh();window.addEventListener("load",function(){window.setTimeout(function(){b.ol=(new Date).getTime()-window.start;b.iml=f;var g=window.performance&&window.performance.timing;g&&(b.rqst=g.responseEnd-g.requestStart,b.rspt=
# g.responseEnd-g.responseStart);for(var p=g=0,D=0,E=0,F=0,N=0,k;k=H[N++];){var l=k[0],v=k[1],O=k[2];k=k[3];var P=0==l,w=l&8,G=l&4;l=1==l||2==l||w&&!G;!l||w||v&&!k||++D;v&&(l&&k&&++g,G&&!k&&++p);P||w?O||++F:v||++E}n+="&ime="+D+("&imex="+E+"&imeh="+F)+("&imea="+g+"&imeb="+p);K(I("all",n,b))},0)},!1)})();}).call(this);})();</script><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">function _setImagesSrc(e,c){function f(b){b.onerror=function(){b.style.display="none"};b.src=c}for(var g=0,a=void 0;a=e[g++];){var d=document.getElementById(a)||document.querySelector('img[data-iid="'+a+'"]');d?f(d):(window.google=window.google||{},google.iir=google.iir||{},google.iir[a]=c)}};</script><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var s='data:image/jpeg;base64,...\x3d';var i=['dimg_15'];_setImagesSrc(i,s);})();</script><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var s='data:image/jpeg;base64,...\x3d\x3d';var i=['dimg_17'];_setImagesSrc(i,s);})();</script><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var s='data:image/jpeg;base64,...';var i=['dimg_19'];_setImagesSrc(i,s);})();</script><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var s='data:image/jpeg;base64,...\x3d';var i=['dimg_21'];_setImagesSrc(i,s);})();</script><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var s='...\x3d';var i=['dimg_23'];_setImagesSrc(i,s);})();</script><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var s='data:image/jpeg;base64,...\x3d';var i=['dimg_25'];_setImagesSrc(i,s);})();</script><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var s='data:image/jpeg;base64,...\x3d';var i=['dimg_27'];_setImagesSrc(i,s);})();</script><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var s='data:image/jpeg;base64,...';var i=['dimg_29'];_setImagesSrc(i,s);})();</script><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var s='data:image/jpeg;base64,...\x3d\x3d';var i=['dimg_31'];_setImagesSrc(i,s);})();</script><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var s='data:image/jpeg;base64,...\x3d\x3d';var i=['dimg_33'];_setImagesSrc(i,s);})();</script><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var s='data:image/jpeg;base64,...\x3d\x3d';var i=['dimg_35'];_setImagesSrc(i,s);})();</script><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var s='data:image/jpeg;base64,...';var i=['dimg_1'];_setImagesSrc(i,s);})();</script><script nonce="QEJ2M6J326YlLpYgbW+lZQ==">(function(){var e='ue1OXuu_F-XC3LUP1_GBkAI';(function(){
# var a=e,b=window.performance&&window.performance.navigation;b&&2==b.type&&window.ping("/gen_204?ct=backbutton&ei="+a);}).call(this);})();(function(){
# var b=[function(){google.tick&&google.tick("load","dcl")}];google.dclc=function(a){b.length?b.push(a):a()};function c(){for(var a;a=b.shift();)a()}window.addEventListener?(document.addEventListener("DOMContentLoaded",c,!1),window.addEventListener("load",c,!1)):window.attachEvent&&window.attachEvent("onload",c);}).call(this);(function(){(function(){google.csct={};google.csct.ps='AOvVaw0Q5u3K_ZjKKftfxy6i17h1\x26ust\x3d1582317369438910';})();})();(function(){(function(){google.csct.rd=true;})();})();(function(){window.xp=function(b){function f(k,g,h){return"xp"+("x"==g?"c":"x")+h}for(var c=/\bxp(x|c)(\d?)\b/,a=b;a;){var e=a.className,d=e.match(c);if(d){d="c"==d[1];a.className=e.replace(c,f);b&&b.setAttribute("aria-expanded",d);if(d)for(b=a.getElementsByTagName("img"),c=0;c<b.length;++c)if(a=b[c],e=a.getAttribute("data-ll"))a.src=e,a.removeAttribute("data-ll");break}a=a.parentElement}};})();(function(){(function(){var id='tsuid37';var lve=false;(function(){
# document.getElementById(id).onclick=function(){window.xp(this);lve&&window.logVe(this)};}).call(this);})();})();(function(){(function(){window.logVe=function(a){a&&a.attributes["data-ved"]&&window.ping("/gen_204?ved="+a.attributes["data-ved"].value)};}).call(this);})();(function(){(function(){var id='tsuid3';var lve=true;(function(){
# document.getElementById(id).onclick=function(){window.xp(this);lve&&window.logVe(this)};}).call(this);})();})();(function(){window.jsl=window.jsl||{};window.jsl.dh=window.jsl.dh||function(i,c,d){try{var e=document.getElementById(i);if(e){e.innerHTML=c;if(d){d();}}else{if(window.jsl.el){window.jsl.el(new Error('Missing ID.'),{'id':i});}}}catch(e){if(window.jsl.el){window.jsl.el(new Error('jsl.dh'));}}};})();(function(){window.jsl.dh('accdef_4','\x3cdiv class\x3d\x22hwc M56Nqc\x22\x3e\x3cdiv class\x3d\x22Z8j5ae\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22ZINbbc xpd O9g5cc uUPGi\x22\x3e\x3cdiv class\x3d\x22kCrYT\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3eSandy briefly weakened to a \x3cspan class\x3d\x22FCUp0c rQMQod\x22\x3etropical storm\x3c/span\x3e on Oct. 27, then gained strength again to become a Category 1 hurricane before turning north toward the U.S. coast. Hurricane Sandy made landfall in the United States about 8 p.m. EDT Oct. 29, striking near Atlantic City, N.J., with \x3cspan class\x3d\x22FCUp0c rQMQod\x22\x3ewinds\x3c/span\x3e of 80 mph.\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3cdiv class\x3d\x22x54gtf\x22\x3e\x3c/div\x3e\x3cdiv class\x3d\x22kCrYT\x22\x3e\x3ca href\x3d\x22/url?q\x3dhttps://www.livescience.com/24380-hurricane-sandy-status-data.html\x26amp;sa\x3dU\x26amp;ved\x3d2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQFnoECAUQAg\x26amp;usg\x3dAOvVaw2sPP6gCbAuLSBQKDSZ09Zo\x22\x3e\x3cspan\x3e\x3cdiv class\x3d\x22BNeawe vvjwJb AP7Wnd\x22\x3eHurricane Sandy: Facts \x26amp; Data | Live Science\x3c/div\x3e\x3c/span\x3e\x3cspan\x3e\x3cdiv class\x3d\x22BNeawe UPmit AP7Wnd\x22\x3ehttps://www.livescience.com \x26gt; 24380-hurricane-sandy-status-data\x3c/div\x3e\x3c/span\x3e\x3c/a\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22PDHNXc\x22\x3e\x3cdiv class\x3d\x22iU269d TeHtNe\x22\x3e\x3cspan class\x3d\x22kXUfPb Vp9uZ\x22\x3e\x3ca class\x3d\x22RtoYlb\x22 href\x3d\x22https://www.google.com/search?ie\x3dUTF-8\x26amp;ei\x3due1OXuu_F-XC3LUP1_GBkAI\x26amp;q\x3dWhat+category+was+Sandy+when+it+hit+NY?\x26amp;sa\x3dX\x26amp;ved\x3d2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQzmd6BAgPEAM\x22\x3eMore results\x3c/a\x3e\x3c/span\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e');})();(function(){(function(){var id='tsuid6';var lve=true;(function(){
# document.getElementById(id).onclick=function(){window.xp(this);lve&&window.logVe(this)};}).call(this);})();})();(function(){window.jsl.dh('accdef_7','\x3cdiv class\x3d\x22hwc M56Nqc\x22\x3e\x3cdiv class\x3d\x22Z8j5ae\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22ZINbbc xpd O9g5cc uUPGi\x22\x3e\x3cdiv class\x3d\x22kCrYT\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3eA year ago this week, \x3cspan class\x3d\x22FCUp0c rQMQod\x22\x3eHurricane Sandy\x3c/span\x3e devastated coastal communities from Jamaica to Canada. In the U.S. alone, the storm caused an estimated $65 billion in damages. The Tri-State area was arguably \x3cspan class\x3d\x22FCUp0c rQMQod\x22\x3ehit the hardest\x3c/span\x3e, and some families still haven\x27t recovered.\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3cdiv class\x3d\x22x54gtf\x22\x3e\x3c/div\x3e\x3cdiv class\x3d\x22kCrYT\x22\x3e\x3ca href\x3d\x22/url?q\x3dhttps://www.businessinsider.com/then-and-now-hurricane-sandy-photos-2013-10\x26amp;sa\x3dU\x26amp;ved\x3d2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQFnoECAoQAg\x26amp;usg\x3dAOvVaw3roPN8v_fsxRwo6Mre-0ZQ\x22\x3e\x3cspan\x3e\x3cdiv class\x3d\x22BNeawe vvjwJb AP7Wnd\x22\x3eHow The Hardest Hit Areas From Hurricane Sandy Look One Year ...\x3c/div\x3e\x3c/span\x3e\x3cspan\x3e\x3cdiv class\x3d\x22BNeawe UPmit AP7Wnd\x22\x3ehttps://www.businessinsider.com \x26gt; then-and-now-hurricane-sandy-photos-2...\x3c/div\x3e\x3c/span\x3e\x3c/a\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22PDHNXc\x22\x3e\x3cdiv class\x3d\x22iU269d TeHtNe\x22\x3e\x3cspan class\x3d\x22kXUfPb Vp9uZ\x22\x3e\x3ca class\x3d\x22RtoYlb\x22 href\x3d\x22https://www.google.com/search?ie\x3dUTF-8\x26amp;ei\x3due1OXuu_F-XC3LUP1_GBkAI\x26amp;q\x3dWhere+did+Hurricane+Sandy+hit+the+hardest?\x26amp;sa\x3dX\x26amp;ved\x3d2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQzmd6BAgPEAY\x22\x3eMore results\x3c/a\x3e\x3c/span\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e');})();(function(){(function(){var id='tsuid9';var lve=true;(function(){
# document.getElementById(id).onclick=function(){window.xp(this);lve&&window.logVe(this)};}).call(this);})();})();(function(){window.jsl.dh('accdef_10','\x3cdiv class\x3d\x22hwc M56Nqc\x22\x3e\x3cdiv class\x3d\x22Z8j5ae\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22ZINbbc xpd O9g5cc uUPGi\x22\x3e\x3cdiv class\x3d\x22kCrYT\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3eStorm surge and high tide\n\n As the storm made landfall, there was a major storm surge along coastal areas on its northern side caused by onshore \x3cspan class\x3d\x22FCUp0c rQMQod\x22\x3ehurricane\x3c/span\x3e-force winds pushing water onto the coastline. Also, with a full moon, high tides were occurring, which only added to the water levels along the shore.\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3cdiv class\x3d\x22x54gtf\x22\x3e\x3c/div\x3e\x3cdiv class\x3d\x22kCrYT\x22\x3e\x3ca href\x3d\x22/url?q\x3dhttps://www.channel4.com/news/by/liam-dutton/blogs/hurricane-sandys-impacts-great\x26amp;sa\x3dU\x26amp;ved\x3d2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQFnoECA0QAg\x26amp;usg\x3dAOvVaw3zDQ3iyPDxi_TN98bpTlP_\x22\x3e\x3cspan\x3e\x3cdiv class\x3d\x22BNeawe vvjwJb AP7Wnd\x22\x3eWhat made Hurricane Sandy\x27s impact so great? \u2013 Liam Dutton ...\x3c/div\x3e\x3c/span\x3e\x3cspan\x3e\x3cdiv class\x3d\x22BNeawe UPmit AP7Wnd\x22\x3ehttps://www.channel4.com \x26gt; news \x26gt; liam-dutton \x26gt; blogs \x26gt; hurricane-sandy...\x3c/div\x3e\x3c/span\x3e\x3c/a\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22PDHNXc\x22\x3e\x3cdiv class\x3d\x22iU269d TeHtNe\x22\x3e\x3cspan class\x3d\x22kXUfPb Vp9uZ\x22\x3e\x3ca class\x3d\x22RtoYlb\x22 href\x3d\x22https://www.google.com/search?ie\x3dUTF-8\x26amp;ei\x3due1OXuu_F-XC3LUP1_GBkAI\x26amp;q\x3dWhy+was+Hurricane+Sandy+so+bad?\x26amp;sa\x3dX\x26amp;ved\x3d2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQzmd6BAgPEAk\x22\x3eMore results\x3c/a\x3e\x3c/span\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e');})();(function(){(function(){var id='tsuid12';var lve=true;(function(){
# document.getElementById(id).onclick=function(){window.xp(this);lve&&window.logVe(this)};}).call(this);})();})();(function(){window.jsl.dh('accdef_13','\x3cdiv class\x3d\x22hwc M56Nqc\x22\x3e\x3cdiv class\x3d\x22Z8j5ae\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22ZINbbc xpd O9g5cc uUPGi\x22\x3e\x3cdiv class\x3d\x22kCrYT\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3eSandy, the most intense storm of the 2012 Atlantic hurricane season, formed in the Caribbean Sea north of Panama on \x3cspan class\x3d\x22FCUp0c rQMQod\x22\x3eOctober 22, 2012\x3c/span\x3e. As it moved northward, the hurricane degenerated into a still-massive extratropical cyclone and made landfall on New Jersey on \x3cspan class\x3d\x22FCUp0c rQMQod\x22\x3eOctober 29\x3c/span\x3e.\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3cdiv class\x3d\x22x54gtf\x22\x3e\x3c/div\x3e\x3cdiv class\x3d\x22kCrYT\x22\x3e\x3ca href\x3d\x22/url?q\x3dhttps://en.wikipedia.org/wiki/Effects_of_Hurricane_Sandy_in_New_Jersey\x26amp;sa\x3dU\x26amp;ved\x3d2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQFnoECA4QAg\x26amp;usg\x3dAOvVaw1qMEjMA7F-sTGSg5ELZBuL\x22\x3e\x3cspan\x3e\x3cdiv class\x3d\x22BNeawe vvjwJb AP7Wnd\x22\x3eEffects of Hurricane Sandy in New Jersey - Wikipedia\x3c/div\x3e\x3c/span\x3e\x3cspan\x3e\x3cdiv class\x3d\x22BNeawe UPmit AP7Wnd\x22\x3ehttps://en.wikipedia.org \x26gt; wiki \x26gt; Effects_of_Hurricane_Sandy_in_New_Jer...\x3c/div\x3e\x3c/span\x3e\x3c/a\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22PDHNXc\x22\x3e\x3cdiv class\x3d\x22iU269d TeHtNe\x22\x3e\x3cspan class\x3d\x22kXUfPb Vp9uZ\x22\x3e\x3ca class\x3d\x22RtoYlb\x22 href\x3d\x22https://www.google.com/search?ie\x3dUTF-8\x26amp;ei\x3due1OXuu_F-XC3LUP1_GBkAI\x26amp;q\x3dWhen+did+Hurricane+Sandy+hit+NJ?\x26amp;sa\x3dX\x26amp;ved\x3d2ahUKEwirgIjX_eDnAhVlIbcAHdd4ACIQzmd6BAgPEAw\x22\x3eMore results\x3c/a\x3e\x3c/span\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e');})();google.drty&&google.drty();</script></body></html>

# %%
category_id = 'BNeawe s3v9rd AP7Wnd'

# %%
val_id = 'BNeawe tAd8D AP7Wnd'

# %%
a = [i.text for i in soup.find_all('span',category_id)]

# %%
b = [i.text for i in soup.find_all('span',val_id)]

# %%
{a[i]:b[i] for i in range(len(a))}
# Out:
# {'Total fatalities': '285',
#  'Highest wind speed': '115\xa0mph',
#  'Lowest pressure': '940\xa0mb',
#  'Date': 'October 22, 2012 – November 2, 2012',
#  'Category': 'Category 3 Hurricane (SSHWS)',
#  'Affected areas': 'Canada, Puerto Rico, Cuba, and more'}

# %%
harvey= Analysis('Hurricane Harvey')

# %%
harvey.crawl()

# %%
harvey.category
# Out:
# 'Tropical Depression (NHC/CPHC) and Category 4 Hurricane (SSHWS)'

# %%
sandy = Analysis('Hurricane Sandy')

# %%
sandy.crawl()

# %%
sandy.category
# Out:
# 'Category 3 Hurricane (SSHWS)'

# %%
dis['date'] = 0
dis['category'] = 0
dis['area_affected'] = 0
dis['damage'] = 0

# %%
titles = np.array(dis.title)

# %%
titles.shape
# Out:
# (51016,)

# %%
import time

# %%
dis.loc[dis.title == 'TORNADO & HEAVY RAINFALL', 'date']
# Out:
# 1    0
# Name: date, dtype: int64

# %%
'I' in 'this'
# Out:
# False

# %%
# t0 = time.time()

# for title in titles: 
#     item = Analysis(title)
#     item.crawl()
#     dis.loc[dis.title == title, 'date'] = item.date
#     dis.loc[dis.title == title, 'category'] = item.category
#     dis.loc[dis.title == title, 'area_affected'] = item.location
#     dis.loc[dis.title == title, 'damage'] = item.damage
#     print(time.time()- t0)

# %%
#dis.to_csv('./data/disaster_dataset.csv')

# %%
hurricanes = list(dis.title) # GExtracting the titiles of each disaster

# %%
hurricanes = [x for x in hurricanes if 'hurricane' in x.lower()] #filtering for hurricanes

# %%
len(hurricanes) # checking the size
# Out:
# 10601

# %%
hurricanes = set(hurricanes) # removing duplicates by taking the set()

# %%
hurricanes = list(hurricanes)

# %%
# my_list = []
# for title in hurricanes:
#     item = Analysis(title)
#     item.crawl()
#     my_dict = {}
#     my_dict['event'] = item.term
#     my_dict['date'] = item.date
#     my_dict['category'] = item.category
#     my_dict['area_affected'] = item.location
#     my_dict['damage'] = item.damage
#     my_dict['fatalities'] = item.death 
#     my_list.append(my_dict)
# result = pd.DataFrame(my_list)
# result.head()

# %%
dot = Analysis(hurricanes[0])

# %%
dot.crawl()

# %%
dot.date

# %%
for i in hurricanes[:10]:
    print(i)
# Out:
# HURRICANE
# HURRICANE ISABEL
# HURRICANE IRMA - SEMINOLE TRIBE OF FLORIDA
# HURRICANE BRET
# HURRICANE KATE
# HURRICANE OMAR
# HURRICANE TUSI
# SEVERE STORMS AND FLOODING ASSOCIATED WITH HURRICANE IKE
# HURRICANE IRMA
# HURRICANE ANDREW

# %%
wrong = [e for e in hurricanes if len(e)>18 ]

# %%
wrong_index = [hurricanes.index(i) for i in wrong]
wrong_index
# Out:
# [2,
#  7,
#  12,
#  15,
#  19,
#  21,
#  27,
#  31,
#  38,
#  40,
#  47,
#  57,
#  62,
#  63,
#  64,
#  65,
#  69,
#  73,
#  79,
#  88,
#  89,
#  90,
#  91,
#  93,
#  98,
#  107]

# %%
len(wrong_index)
# Out:
# 9

# %%
hurricanes = list(set(hurricanes))

# %%
# fixing the names of the hurricanes 

hurricanes[wrong_index[0]] = 'HURRICANE FRAN'
hurricanes[wrong_index[1]] = 'HURRICANE BOB'
hurricanes[wrong_index[2]] = 'HURRICANE GEORGES'
hurricanes[wrong_index[3]] = 'HURRICANE IKE'
hurricanes[wrong_index[4]] = 'HURRICANE GUSTAV'
hurricanes[wrong_index[5]] = 'HURRICANE GEORGES'
hurricanes[wrong_index[6]] = 'HURRICANE FLOYD'
hurricanes[wrong_index[7]] = 'HURRICANE KATRINA'
hurricanes[wrong_index[8]] = 'HURRICANE IRENE'
hurricanes[wrong_index[9]] = 'HURRICANE FRAN'
hurricanes[wrong_index[10]] = 'HURRICANE GEORGES'
hurricanes[wrong_index[11]] = 'HURRICANE DAVID'
hurricanes[wrong_index[12]] = None
hurricanes[wrong_index[13]] = 'HURRICANE SANDY '
hurricanes[wrong_index[14]] = 'HURRICANE JEANNE'
hurricanes[wrong_index[15]] = None
hurricanes[wrong_index[16]] = 'HURRICANE LENNY'
hurricanes[wrong_index[17]] = 'HURRICANE KATRINA'
hurricanes[wrong_index[18]] = 'HURRICANE FRAN'
hurricanes[wrong_index[19]] = 'HURRICANE BOB'
hurricanes[wrong_index[20]] = 'HURRICANE CHARLEY'
hurricanes[wrong_index[21]] =  'HURRICANE IRMA'

# %%
hurricanes.pop(hurricanes.index(None))

# %%
hurricanes.pop(hurricanes.index(None))

# %%
wrong = [e for e in hurricanes if len(e)>17 ] # I want to change titles that don't

# %%
wrong
# Out:
# ['HURRICANE & FLOODS',
#  'HURRICANE FREDERIC',
#  'FLOODS & HURRICANE',
#  'HURRICANE BOB & FLOODING',
#  'HURRICANE GEORGES - 18 SEP 98',
#  'HURRICANE & SEVERE STORM',
#  'HURRICANE FLORENCE',
#  'HURRICANE HORTENSE',
#  'HURRICANE GEORGES (DIRECT FEDERAL ASSIST FIRST 72 HRS)']

# %%
wrong_index = [hurricanes.index(i) for i in wrong]
wrong_index
# Out:
# [13, 43, 82, 89, 91, 96, 99, 100, 105]

# %%
hurricanes[wrong_index[0]] = None
hurricanes[wrong_index[1]] = 'HURRICANE FREDERIC'
hurricanes[wrong_index[2]] = None
hurricanes[wrong_index[3]] = 'HURRICANE BOB'
hurricanes[wrong_index[4]] = 'HURRICANE GEORGES'
hurricanes[wrong_index[5]] = None
hurricanes[wrong_index[6]] = 'HURRICANE FLORENCE'
hurricanes[wrong_index[7]] = 'HURRICANE HORTENSE'
hurricanes[wrong_index[8]] = 'HURRICANE GEORGES'

# %%
hurricanes = list(set(hurricanes))
hurricanes
# Out:
# ['HURRICANE ISABEL',
#  'HURRICANE BRET',
#  'HURRICANE SANDY ',
#  'HURRICANE KATE',
#  'HURRICANE OMAR',
#  'HURRICANE TUSI',
#  'HURRICANE IRMA',
#  'HURRICANE ANDREW',
#  'HURRICANE HUGO',
#  'HURRICANE OPHELIA',
#  'HURRICANE ELENA',
#  'HURRICANE FLOYD',
#  'HURRICANE CARLA',
#  'HURRICANE CINDY',
#  'HURRICANE VAL',
#  'HURRICANE HILDA',
#  'HURRICANE KATRINA',
#  'HURRICANE BERTHA',
#  'HURRICANE DOLLY',
#  'HURRICANE IVAN',
#  'HURRICANE LANE',
#  'HURRICANE RITA',
#  'HURRICANE GUSTAV',
#  'HURRICANE BELLE',
#  'HURRICANE CAMILLE',
#  'HURRICANE WILMA',
#  'HURRICANE DORIAN',
#  'HURRICANE INIKI',
#  'HURRICANE DAVID',
#  'HURRICANE GILBERT',
#  'HURRICANE CHARLEY',
#  'HURRICANE IKE',
#  'HURRICANE FREDERIC',
#  'HURRICANE GEORGES',
#  'HURRICANE ISAAC',
#  'HURRICANE OFA',
#  'HURRICANE GLADYS',
#  'HURRICANE CLEO',
#  'HURRICANE ALICIA',
#  'HURRICANE EDITH',
#  'HURRICANE ALLEN',
#  'HURRICANE IRENE',
#  'HURRICANE NATE',
#  'HURRICANE DIANA',
#  'HURRICANE HERMINE',
#  'HURRICANE DORA',
#  'HURRICANE DONNA',
#  'HURRICANE BARRY',
#  'HURRICANE MARIA',
#  'HURRICANE JEANNE',
#  'HURRICANE JUAN',
#  'HURRICANE GLORIA',
#  'HURRICANE EARL',
#  'HURRICANE BETSY',
#  'HURRICANE BEULAH',
#  'HURRICANE MICHAEL',
#  'HURRICANE FRAN',
#  'HURRICANE BOB',
#  'HURRICANE ERIN',
#  'HURRICANE ALEX',
#  'HURRICANE OPAL',
#  'HURRICANE DENNIS',
#  'HURRICANE BONNIE',
#  'HURRICANE MATTHEW',
#  'HURRICANE LILI',
#  'HURRICANE HARVEY',
#  'HURRICANE CARMEN',
#  'HURRICANE LENNY',
#  'HURRICANE SANDY',
#  'HURRICANE DOT',
#  'HURRICANE DEAN',
#  'HURRICANE GRORGES',
#  'HURRICANE MARILYN',
#  'HURRICANE FLORENCE',
#  'HURRICANE HORTENSE',
#  'HURRICANE EMILY',
#  'HURRICANE & FLOOD',
#  'HURRICANE FRANCES',
#  'HURRICANE CELIA']

# %%
dis.disasterNumber
# Out:
# 0           1
# 1           2
# 2           3
# 3           6
# 4           4
#          ...
# 51011    4473
# 51012    4473
# 51013    4473
# 51014    4473
# 51015    4473
# Name: disasterNumber, Length: 51016, dtype: int64

# %%
hurricanes.pop(hurricanes.index(None ))

# %%
hurricanes.pop(hurricanes.index('HURRICANES'))
# Out:
# 'HURRICANES'

# %%
hurricanes.pop(hurricanes.index('HURRICANE'))
# Out:
# 'HURRICANE'

# %%
hurricanes.pop(hurricanes.index('HURRICANE & FLOOD'))
# Out:
# 'HURRICANE & FLOOD'

# %%
# creating dataframe using the Analysis class
my_list = []
for title in hurricanes:
    item = Analysis(title)
    item.crawl()
    my_dict = {}
    my_dict['event'] = item.term
    my_dict['date'] = item.date
    my_dict['category'] = item.category
    my_dict['area_affected'] = item.location
    my_dict['damage'] = item.damage
    my_dict['fatalities'] = item.death 
    my_list.append(my_dict)
result = pd.DataFrame(my_list)
result.head()
# Out:
#               event                                    date  \
# 0  HURRICANE ISABEL  September 6, 2003 – September 20, 2003
# 1    HURRICANE BRET       August 18, 1999 – August 25, 1999
# 2  HURRICANE SANDY      October 22, 2012 – November 2, 2012
# 3    HURRICANE KATE   November 15, 1985 – November 23, 1985
# 4    HURRICANE OMAR     October 13, 2008 – October 21, 2008
#
#                        category  \
# 0  Category 5 Hurricane (SSHWS)
# 1  Category 4 Hurricane (SSHWS)
# 2  Category 3 Hurricane (SSHWS)
# 3  Category 3 Hurricane (SSHWS)
# 4  Category 4 Hurricane (SSHWS)
#
#                                        area_affected                   damage  \
# 0  Puerto Rico, Washington, D.C., The Bahamas, an...  $5.5 billion (2003 USD)
# 1                                   Mexico and Texas   $15 million (1999 USD)
# 2              Puerto Rico, Jamaica, Haiti, and more                     None
# 3               Cuba, Florida, The Bahamas, and more  $700 million (1985 USD)
# 4       Puerto Rico, Venezuela, Montserrat, and more   $80 million (2008 USD)
#
#   fatalities
# 0         51
# 1          7
# 2        285
# 3         15
# 4          1

# %%
result.shape
# Out:
# (78, 6)

# %%
set(dis.loc[dis['title'] == hurricanes[2],'disasterNumber'])

# %%
hurricanes[2]

# %%
result.to_csv('./data/updated_hurricane_clean.csv', index=False)
