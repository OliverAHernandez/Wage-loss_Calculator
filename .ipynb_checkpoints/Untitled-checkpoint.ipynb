# %%
import pandas as pd

# %%
ind_dis = pd.read_csv('./data/individual_disasters.csv')
df = pd.read_csv('./data/census.csv')

# %%
ind_dis['affected_zips'][0]
# Out:
# '[99556, 99568, 99610, 99572, 99603, 99605, 99669, 99611, 99631, 99639, 99663, 99664, 99672, 99682, 99501, 99502, 99503, 99504, 99507, 99508, 99509, 99510, 99511, 99513, 99514, 99515, 99516, 99517, 99518, 99519, 99520, 99521, 99522, 99523, 99524, 99529, 99530, 99599, 99695, 99645, 99652, 99654, 99667, 99674, 99676, 99683, 99687, 99688, 99694, 99574]'

# %%
ind_dis
# Out:
#     Unnamed: 0                                   event        type  severity  \
# 0            0                    Anchorage Earthquake  Earthquake       3.5
# 1            1                 Kilauea Quake + Volcano  Earthquake       3.4
# 2            2                     New Orleans Tornado     Tornado       3.0
# 3            3                         Wisconsin Flood       Flood       2.0
# 4            4                   California Earthquake  Earthquake       3.5
# 5            5                         Georgia Tornado     Tornado       3.0
# 6            6                      Washington Tornado     Tornado       2.0
# 7            7                          HURRICANE BRET   Hurricane       4.0
# 8            8                          HURRICANE IRMA   Hurricane       5.0
# 9            9                        HURRICANE ANDREW   Hurricane       5.0
# 10          10                          HURRICANE LANE   Hurricane       5.0
# ...
